# %% [markdown]
# 2022 Oct 21h, Transformer refined code in progress. Need to save model config
#
# 2022 Sep 12th, testing DIY data normalization
#
# 2022 July 15th, Transformer can't use Weight_decay!
#
# 2022 July 14th, editted for Prelim model structure selection.
#
# 2022 July 1st, editted for Prelim Results plotting.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: einops in /usr/local/lib/python3.8/dist-packages (0.6.0)

# %%
# !pip install thop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: thop in /usr/local/lib/python3.8/dist-packages (0.1.1.post2209072238)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from thop) (1.13.0+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->thop) (4.4.0)

# %%
import torch
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time
import heapq
import os
import math
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd
#from utils import progress_bar
from torch.autograd import Variable
import sys
from copy import deepcopy
import random
import collections
from scipy import signal
from drive.MyDrive.Wireless_Transformer.PSDshow import imshow
from drive.MyDrive.Wireless_Transformer.wrt import WrT # customized design of Wireless Transformer
from drive.MyDrive.Wireless_Transformer.wrt import WrTOct26 # new version WrT editting mean/class
from drive.MyDrive.Wireless_Transformer.AlexNet1D import AlexNet1D
# /content/drive/MyDrive/Wireless_Transformer/AlexNet1D.py
from torch.utils.data import Dataset, DataLoader
from pytz import timezone
TMZ = timezone('EST')
import datetime
import shutil
device = torch.device("cuda")
from torchsummary import summary 
from thop import profile
# torch.manual_seed(0)

# %%
class ToyDatasetMaker(Dataset):
    "Toy version that wrap data/label tensor list into pytorch dataset"
    def __init__(self, data_list, label_list, transformFunc=transforms.Compose([ ]), norm_config=(1,1) ):
        """
        db: a list of input signal tensors, 
        label_list: a list of data labels, align with elements in db.
        """
        self.datasets = data_list
        self.label_list = label_list
        self.transformFunc = transformFunc
        self.norm_config = norm_config
    def __getitem__(self, i):
        img = self.datasets[i]
        img = self.transformFunc(img)
        img = (img-self.norm_config[0])/self.norm_config[1] # added for normalizing non-image
        class_label = self.label_list[i]
        return img, class_label

    def __len__(self):
        return len(self.label_list)

def adjust_learning_rate(optimizer, epoch):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    epoch_inter = 20
#     print("Decrease learning rate every %d epoch by %2f" %(epoch_inter, des))
    #lr = 0.01 * (des ** (epoch // epoch_inter))
    bs = 1 #0.4 #0.2
    lr = 0.0003 * bs ** (epoch/epoch_inter)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

def train(model, trainloader, epoch, volum):
  #Transformer fail with weight_decay
  optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=2/(100*volum) )
  # optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0 )
  adjust_learning_rate(optimizer, epoch)
  running_loss = 0.0
  model.train()
  for i, data in enumerate(trainloader, 0):
      # get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      #inputs = inputs.to(device)
      # if type(model).__name__ == 'WrT':
      inputs = Variable(inputs.view(-1, 1,1,datas_tr[0].size(0)).to(device)) #640
      # inputs = Variable(inputs.view(-1,datas_tr[0].size(0)).to(device))
      labels = Variable(labels.to(device))
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward + backward + optimize
      outputs = model(inputs)
      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()
      # print statistics
      running_loss += loss.item()
  print('Learning rate:', optimizer.param_groups[0]['lr'])
  return model, running_loss

def test(model, testloader, thresh = 0):
  total = 0 #sum of occupation and emptiness
  total_ocp = 0 #occupied bands
  total_emp = 0 #empty bands
  correct = 0
  correct_ocp = 0
  correct_emp = 0
  model.eval()
  # since we're not training, we don't need to calculate the gradients for our outputs
  with torch.no_grad():
      for data in testloader:
          inputs, labels = data
          inputs = Variable(inputs.view(-1,1,1,datas_tr[0].size(0) ).to(device)) #10bands=>640, 8bands=>512
          labels = Variable(labels.to(device)) 
          total_batch = float( torch.tensor(labels.size()).prod() ) 
          total += total_batch
          total_ocp += float(labels.sum())  #occupied bands
          total_emp += float(total_batch - labels.sum())  #empty bands
          # calculate outputs by running images through the network
          outputs = ( model(inputs)> thresh ).bool()
          labels = labels.bool()
          # the class with the highest energy is what we choose as prediction
          correct_ocp += (outputs * labels).sum() 
          correct_emp += (~outputs * ~labels).sum()
          correct = correct_ocp + correct_emp
          if (outputs * labels).sum()+(~outputs * ~labels).sum() != (~(outputs^labels)) .sum():
            print('wrong!', (outputs * labels).sum()+(~outputs * ~labels).sum(),'!=', (~(outputs^labels)).sum())

  # print(f'Accuracy of the network on the test data: {100 * correct/total} %')
  print(f'Testing accuracy: {100 * correct/total} %; detection rate: {100*correct_ocp/total_ocp}; false alarm: {100-100*correct_emp/total_emp}')
  return (correct/total, correct_ocp/total_ocp, correct_emp/total_emp) 

def setDir(filepath):
  # if directory not exist, create. if directory already exist, empty it.
  if not os.path.exists(filepath):
    os.makedirs(filepath)
  else:
    print('Directory already exists')
    shutil.rmtree(filepath, ignore_errors = True)
    os.mkdir(filepath)        

for volum in [2400, 2400, 3200, 3200, 4000, 4000]: #[200, 400, 800, 1600, 2400, 3200, 4000]: #[20, 50, 100, 200]: #[400,200,100]:
  SNR = -6
  # volum = 4000 # 4000 samples per occupancy pattern
  # address1 =  '/content/drive/MyDrive/Wireless_Transformer/MesBondSW/' #WFSC/, SFWC/, AllW/
  address1 =  '/content/drive/MyDrive/Wireless_Transformer/LeftRightIndep/' #LeftRightIndep version
  # name1 = 'T_8b3P1sig_SNR'+str(SNR)+'.pth' #data of PU with the same sig
  name1 = 'T_10b5P5sig_SNR'+str(SNR)+'vol'+str(volum)+'.pth' #10bands, 5PUs, 5 kinds of sig, training & testing together
  # name1 = 'Old_Data/T_8b5P_SNR-10.pth' # 10bands failed, test on 8bands. reason found: shouldn't use weight decay for WrT 
  # name1 = 'Old_Data/T_8b3P3sig_SNR'+str(SNR)+'.pth' #8 band data with PU have the same sig
  # data_dict = torch.load(address1 + name1)
  #==================================Data_path_override======================================
  # data_dict = torch.load( '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/221024_13_53/221024_13_53Data_SNR-5vol4000.pth')
  # datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/221027_21_14/221027_21_14Data_SNR-5vol4000.pth'
  # datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/221030_17_33/221030_17_33Data_SNR-5vol4000.pth'
  datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/221030_21_21/221030_21_21Data_SNR'+str(SNR)+'vol4000.pth'

  data_dict = torch.load( datadir)
  datas_te = data_dict['testing data list']
  labels_te = data_dict['testing label list']

  # datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/varyingsize/221117_21_33/221117_21_33Data_SNR-6vol'+str(volum)+'.pth'
  datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/varyingsize/Data_SNR-6vol'+str(volum)+'.pth'
  data_dict1 = torch.load( datadir)
  print('Dataset description:', data_dict1['Description'] )
  datas_tr = data_dict1['training data list']
  labels_tr = data_dict1['training label list']

  num_bands = labels_te[0] 

  #calculating mean and std
  datas_all = datas_tr+datas_te
  data_tens =torch.cat(datas_all,dim=0)
  (data_mean, data_std) = ( torch.mean(data_tens).item(), torch.std(data_tens).item() )
  print(data_mean, data_std)

  trainset= ToyDatasetMaker(datas_tr, labels_tr, norm_config=(data_mean, data_std) )
  testset= ToyDatasetMaker(datas_te, labels_te, norm_config=(data_mean, data_std) )
  train_loader = DataLoader(trainset, batch_size=min(500, volum), shuffle=True, num_workers=12, pin_memory=True)
  test_loader = DataLoader(testset, batch_size=1000, shuffle=False, num_workers=12, pin_memory=True)

  # WrT_var={
  #     'spectra_size': (1, datas_tr[0].size(0)),
  #     'patch_size': (1,320),
  #     'num_bands': labels_te[0].size(0),
  #     'dim': 64,
  #     'depth': 3,
  #     'heads': 4,
  #     'mlp_dim': 128,
  #     'dropout': .1,
  #     'dim_head': 16,
  #     'emb_dropout': .1,
  #     'pool': 'mean',
  #     'Description': 'None',
  #     'Data_dir': datadir,
  # }


  WrT_var={ #
  'spectra_size': (1,datas_tr[0].size(0)),'patch_size':(1,64),'num_bands':labels_te[0].size(0),'dim':16,
  'depth':1,'heads':4,'mlp_dim':32,'dropout':.1,'dim_head':8,'emb_dropout':.1,'pool':'mean','Description':'None', 'Data_dir': datadir,} 
  #;

  # WrT_var={ #1114
  # 'spectra_size': (1,datas_tr[0].size(0)),'patch_size':(1,64),'num_bands':labels_te[0].size(0),'dim':4,
  # 'depth':1,'heads':4,'mlp_dim':4,'dropout':.1,'dim_head':4,'emb_dropout':.1,'pool':'mean','Description':'None', 'Data_dir': datadir,} 
  # #;

  # from IPython.core.interactiveshell import ensure_dir_exists
  v = WrTOct26(
      spectra_size = WrT_var['spectra_size'],
      patch_size = WrT_var['patch_size'],
      num_bands = WrT_var['num_bands'],
      dim = WrT_var['dim'], # 512
      depth = WrT_var['depth'], #6
      heads = WrT_var['heads'], #8
      mlp_dim = WrT_var['mlp_dim'], #1024
      dropout = WrT_var['dropout'],
      dim_head = WrT_var['dim_head'],
      emb_dropout = WrT_var['emb_dropout'],
      pool = WrT_var['pool'],
  )

  # for i, data in enumerate(train_loader, 0):
  #   if i>0:
  #     break
  #   inputs, labels = data
  #   inputs = Variable(inputs.view(-1, 1,1,datas_tr[0].size(0)).to(device))
  #   v(inputs)

  criterion = nn.BCEWithLogitsLoss()
  # summary(v, (1,1,640))

  macs, params = profile(v, inputs =(torch.randn(1, 1, 1, 640), )) #model on CPU
  print('macs are :\n',macs)
  print('params are :\n',params)
  v = v.to(device)

  nepoch = 100
  acc_list = []
  acc_ocp_list = []
  fa_list = []
  # plt.title("Global Model ACC of the proposed method")
  max_acc = 0
  now=datetime.datetime.now(TMZ) #time watermark
  time_watermark = now.strftime('%y%m%d_%H_%M')
  print('model watermark',time_watermark)
  address_model = '/content/drive/MyDrive/Wireless_Transformer/Saved_Models/'+type(v).__name__+'/VaryingVolum/'+str(volum)+'_'+time_watermark+'/' #root dir for saved models
  #child dir nbamed by time_watermark
  setDir(address_model) # if dir not exist, create. if dir already exist, empty it.
  name1 = type(v).__name__ +'_SNR'+str(SNR)+'vol'+str(volum)+'.pth'
  print('Model saved to dir:\n', address_model+name1)
  torch.save(WrT_var, address_model+type(v).__name__+'config.pth') #Save WrT model config
  txt=open(address_model+'Datasetdir.txt',"w").write(datadir+' very small model To find Gap')#save dataset dir (dataset version)
  
  for i in range(nepoch):
    print('Epoch', i+1,':')      
    acc_ = test(v, test_loader)
    
    if acc_[0].cpu().item() > max_acc:
      max_acc = acc_[0].cpu().item()
      torch.save(v.state_dict(), address_model+name1)

    acc_list.append( acc_[0].cpu().item())
    acc_ocp_list.append(acc_[1].cpu().item())
    fa_list.append((1-acc_[2]).cpu().item())  

    #uniform the y axis, label SNR on title
    v, training_loss = train(v, train_loader, epoch=i, volum=volum)# Test first and train then version
    print(f'Max accuracy: {100 * max_acc} %; training loss: , {training_loss}')

  plt.figure(1,figsize=(5, 4), dpi=80) 
  l1, = plt.plot( acc_list, color='blue',label='Avg Acc/band')
  l2, = plt.plot( fa_list, color='red', label='FA')
  l3, = plt.plot( acc_ocp_list, color='black', label='Acc 4 busy')
  plt.legend(loc='lower right')
  plt.title('SNR='+str(SNR)+'dB,'+ type(v).__name__+ ' Model ACC reaches %.3f %%' %  (100*max(acc_list))  )
  plt.show()

  plt.figure(2,figsize=(5, 4), dpi=80)
  l1, = plt.plot( acc_list, color='blue',label='Avg Acc/band')
  # l2, = plt.plot( fa_list, color='red', label='FA')
  # l3, = plt.plot( acc_ocp_list, color='black', label='Acc 4 busy')
  plt.legend(loc='lower right')
  plt.title('SNR='+str(SNR)+'dB,'+ type(v).__name__+ ' Model ACC reaches %.3f %%' %  (100*max(acc_list))  )
  plt.show()

  df1 = pd.DataFrame() # save statics to excel
  # df1['acc_old'] = xx
  df1['Accuracy'] = acc_list
  df1['FA'] = fa_list
  df1['PD'] = acc_ocp_list 

  with pd.ExcelWriter(address_model + "converg"+"SNR"+str(SNR)+".xlsx", mode='w') as writer:  #mode was 'a'
    df1.to_excel(writer, sheet_name=type(v).__name__)
  print('Statics saved to excel:', address_model + "converg"+"SNR"+str(SNR)+".xlsx")

  finish_tim=datetime.datetime.now(TMZ)
  print('Time spent for running'+str(nepoch)+'epochs',finish_tim - now)

  '''ROC module of current model'''
  pd3= []
  pfa3 = []
  v.load_state_dict(torch.load(address_model+name1))

  for thresh_val in [ (i-50)/12.5 for i in range(100)]: 
    #[i*0.9999/100 for i in list(range(1,100))]
    # in [(1-i/50)*5e-8+1e-10 for i in list(range(50))]
      CNNoutput = test(v, test_loader, thresh=thresh_val) #
      #testnets( net_list, class_dir, tol_test_loader, thresh_sig = thresh_val )
      pd3.append(CNNoutput[1].to(torch.device('cpu')).item())
      pfa3.append(1-CNNoutput[2].to(torch.device('cpu')).item())

  plt.title("ROC of " +type(v).__name__+ " method in SNR="+str(SNR)+"dB")
  l3, = plt.plot(pfa3, pd3, '.', color='green', label='Transformer')
  plt.legend(loc='lower right')
  plt.show()

  dfroc = pd.DataFrame() # save statics to excel
  # df1['acc_old'] = xx
  dfroc['PD'] = pd3
  dfroc['PFA'] = pfa3


  with pd.ExcelWriter(address_model + "ROC_SNR"+str(SNR)+".xlsx", mode='w') as writer:  #mode was 'a'
    dfroc.to_excel(writer, sheet_name=type(v).__name__)
  print('Statics saved to excel:', address_model + "ROC_SNR"+str(SNR)+".xlsx")

  ROC_dict = {
      'pd':pd3,
      'pfa':pfa3,
  }
  torch.save(ROC_dict, address_model+type(v).__name__+'ROC.pth')
  print('ROC in Lists saved to:', address_model+type(v).__name__+'ROC.pth')
# Out:
# Dataset description: cleanPSD64.pth, SNR-6dB, 10bands, 6PUs, 64pts/band.
# 3.279839277267456 2.5345261096954346
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register count_softmax() for <class 'torch.nn.modules.activation.Softmax'>.
# macs are :
#  49312.0
# params are :
#  6362.0
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# model watermark 221212_19_41
# Model saved to dir:
#  /content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/VaryingVolum/2400_221212_19_41/WrTOct26_SNR-6vol2400.pth
# Epoch 1 :
# Testing accuracy: 49.78633117675781 %; detection rate: 44.767189025878906; false alarm: 45.19453048706055
# Learning rate: 0.0003
# Max accuracy: 49.78632926940918 %; training loss: , 193.26317900419235
# Epoch 2 :
# Testing accuracy: 71.775390625 %; detection rate: 71.4937515258789; false alarm: 27.942962646484375
# Learning rate: 0.0003
# Max accuracy: 71.77539467811584 %; training loss: , 147.39915889501572
# Epoch 3 :
# Testing accuracy: 73.70938110351562 %; detection rate: 71.85469055175781; false alarm: 24.435935974121094
# Learning rate: 0.0003
# Max accuracy: 73.70938062667847 %; training loss: , 141.92754366993904
# Epoch 4 :
# Testing accuracy: 74.580078125 %; detection rate: 72.9976577758789; false alarm: 23.837493896484375
# Learning rate: 0.0003
# Max accuracy: 74.5800793170929 %; training loss: , 140.14009141921997
# Epoch 5 :
# Testing accuracy: 74.75508117675781 %; detection rate: 74.70781707763672; false alarm: 25.197654724121094
# Learning rate: 0.0003
# Max accuracy: 74.75508451461792 %; training loss: , 139.37323623895645
# Epoch 6 :
# Testing accuracy: 74.80547332763672 %; detection rate: 71.65312957763672; false alarm: 22.04218292236328
# Learning rate: 0.0003
# Max accuracy: 74.80547428131104 %; training loss: , 138.98252454400063
# Epoch 7 :
# Testing accuracy: 74.86953735351562 %; detection rate: 72.5; false alarm: 22.76093292236328
# Learning rate: 0.0003
# Max accuracy: 74.86953735351562 %; training loss: , 138.7759847342968
# Epoch 8 :
# Testing accuracy: 74.8863296508789 %; detection rate: 73.9195327758789; false alarm: 24.146873474121094
# Learning rate: 0.0003
# Max accuracy: 74.88633394241333 %; training loss: , 138.542720079422
# Epoch 9 :
# Testing accuracy: 74.88555145263672 %; detection rate: 73.86172485351562; false alarm: 24.090621948242188
# Learning rate: 0.0003
# Max accuracy: 74.88633394241333 %; training loss: , 138.44468215107918
# Epoch 10 :
# Testing accuracy: 74.81914520263672 %; detection rate: 74.16250610351562; false alarm: 24.524215698242188
# Learning rate: 0.0003
# Max accuracy: 74.88633394241333 %; training loss: , 138.27071592211723
# Epoch 11 :
# Testing accuracy: 74.86836242675781 %; detection rate: 73.38359832763672; false alarm: 23.646873474121094
# Learning rate: 0.0003
# Max accuracy: 74.88633394241333 %; training loss: , 138.23032361268997
# Epoch 12 :
# Testing accuracy: 74.84844207763672 %; detection rate: 74.76875305175781; false alarm: 25.071868896484375
# Learning rate: 0.0003
# Max accuracy: 74.88633394241333 %; training loss: , 138.19097223877907
# Epoch 13 :
# Testing accuracy: 74.84492492675781 %; detection rate: 72.5625; false alarm: 22.872650146484375
# Learning rate: 0.0003
# Max accuracy: 74.88633394241333 %; training loss: , 138.04891508817673
# Epoch 14 :
# Testing accuracy: 74.904296875 %; detection rate: 72.97500610351562; false alarm: 23.166404724121094
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 138.0676797926426
# Epoch 15 :
# Testing accuracy: 74.8570327758789 %; detection rate: 73.2515640258789; false alarm: 23.537498474121094
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.9904007911682
# Epoch 16 :
# Testing accuracy: 74.8960952758789 %; detection rate: 72.82344055175781; false alarm: 23.03125
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.92399886250496
# Epoch 17 :
# Testing accuracy: 74.89375305175781 %; detection rate: 73.02578735351562; false alarm: 23.23828125
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.87967643141747
# Epoch 18 :
# Testing accuracy: 74.85781860351562 %; detection rate: 72.7007827758789; false alarm: 22.985153198242188
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.84261119365692
# Epoch 19 :
# Testing accuracy: 74.8687515258789 %; detection rate: 74.1187515258789; false alarm: 24.381248474121094
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.78306078910828
# Epoch 20 :
# Testing accuracy: 74.87187957763672 %; detection rate: 72.59687805175781; false alarm: 22.853118896484375
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.8523617386818
# Epoch 21 :
# Testing accuracy: 74.90117645263672 %; detection rate: 72.98281860351562; false alarm: 23.180465698242188
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.80022910237312
# Epoch 22 :
# Testing accuracy: 74.85391235351562 %; detection rate: 73.23672485351562; false alarm: 23.528900146484375
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.71769833564758
# Epoch 23 :
# Testing accuracy: 74.86328125 %; detection rate: 74.49453735351562; false alarm: 24.767967224121094
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.7630476951599
# Epoch 24 :
# Testing accuracy: 74.89141082763672 %; detection rate: 72.16015625; false alarm: 22.377342224121094
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.7549479007721
# Epoch 25 :
# Testing accuracy: 74.8941421508789 %; detection rate: 72.73359680175781; false alarm: 22.9453125
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.68601629137993
# Epoch 26 :
# Testing accuracy: 74.87812805175781 %; detection rate: 72.4742202758789; false alarm: 22.71796417236328
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.69473427534103
# Epoch 27 :
# Testing accuracy: 74.8863296508789 %; detection rate: 72.80078125; false alarm: 23.028121948242188
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.7247580587864
# Epoch 28 :
# Testing accuracy: 74.8804702758789 %; detection rate: 72.12344360351562; false alarm: 22.36249542236328
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.68865913152695
# Epoch 29 :
# Testing accuracy: 74.87617492675781 %; detection rate: 72.55156707763672; false alarm: 22.799217224121094
# Learning rate: 0.0003
# Max accuracy: 74.90429878234863 %; training loss: , 137.61443093419075
# Epoch 30 :
# Testing accuracy: 74.919921875 %; detection rate: 73.15078735351562; false alarm: 23.310935974121094
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.68359553813934
# Epoch 31 :
# Testing accuracy: 74.87149047851562 %; detection rate: 73.53203582763672; false alarm: 23.7890625
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.61254519224167
# Epoch 32 :
# Testing accuracy: 74.86836242675781 %; detection rate: 72.62031555175781; false alarm: 22.883590698242188
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.6061794757843
# Epoch 33 :
# Testing accuracy: 74.89336395263672 %; detection rate: 72.46875; false alarm: 22.682029724121094
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.61725383996964
# Epoch 34 :
# Testing accuracy: 74.89688110351562 %; detection rate: 73.56875610351562; false alarm: 23.774993896484375
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.59081760048866
# Epoch 35 :
# Testing accuracy: 74.9039077758789 %; detection rate: 72.72969055175781; false alarm: 22.921875
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.547983199358
# Epoch 36 :
# Testing accuracy: 74.8863296508789 %; detection rate: 72.93203735351562; false alarm: 23.15937042236328
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.52942883968353
# Epoch 37 :
# Testing accuracy: 74.87890625 %; detection rate: 71.0703125; false alarm: 21.3125
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.56647250056267
# Epoch 38 :
# Testing accuracy: 74.89453125 %; detection rate: 73.23672485351562; false alarm: 23.447654724121094
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.56231021881104
# Epoch 39 :
# Testing accuracy: 74.8984375 %; detection rate: 72.26171875; false alarm: 22.46484375
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.54271176457405
# Epoch 40 :
# Testing accuracy: 74.865234375 %; detection rate: 73.87969207763672; false alarm: 24.149215698242188
# Learning rate: 0.0003
# Max accuracy: 74.91992712020874 %; training loss: , 137.58714205026627
# Epoch 41 :
# Testing accuracy: 74.92031860351562 %; detection rate: 73.0015640258789; false alarm: 23.160934448242188
# Learning rate: 0.0003
# Max accuracy: 74.92031455039978 %; training loss: , 137.54831793904305
# Epoch 42 :
# Testing accuracy: 74.93476867675781 %; detection rate: 72.3257827758789; false alarm: 22.45624542236328
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.53190845251083
# Epoch 43 :
# Testing accuracy: 74.89765930175781 %; detection rate: 73.4898452758789; false alarm: 23.69452667236328
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.51091215014458
# Epoch 44 :
# Testing accuracy: 74.87812805175781 %; detection rate: 71.97187805175781; false alarm: 22.215621948242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.50695285201073
# Epoch 45 :
# Testing accuracy: 74.8765640258789 %; detection rate: 73.21875; false alarm: 23.465621948242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.5183638036251
# Epoch 46 :
# Testing accuracy: 74.89531707763672 %; detection rate: 74.07734680175781; false alarm: 24.286712646484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.51274958252907
# Epoch 47 :
# Testing accuracy: 74.90742492675781 %; detection rate: 73.52734375; false alarm: 23.712493896484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.5297462940216
# Epoch 48 :
# Testing accuracy: 74.865234375 %; detection rate: 73.51250457763672; false alarm: 23.782028198242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.53791177272797
# Epoch 49 :
# Testing accuracy: 74.90117645263672 %; detection rate: 73.68203735351562; false alarm: 23.879684448242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.48161539435387
# Epoch 50 :
# Testing accuracy: 74.86054992675781 %; detection rate: 73.72344207763672; false alarm: 24.002342224121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.45863869786263
# Epoch 51 :
# Testing accuracy: 74.892578125 %; detection rate: 72.69921875; false alarm: 22.9140625
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.51980409026146
# Epoch 52 :
# Testing accuracy: 74.865234375 %; detection rate: 73.2632827758789; false alarm: 23.532806396484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.47523015737534
# Epoch 53 :
# Testing accuracy: 74.91445922851562 %; detection rate: 72.92500305175781; false alarm: 23.096092224121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.48160442709923
# Epoch 54 :
# Testing accuracy: 74.88164520263672 %; detection rate: 73.72891235351562; false alarm: 23.965621948242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.44627809524536
# Epoch 55 :
# Testing accuracy: 74.86640930175781 %; detection rate: 72.29531860351562; false alarm: 22.5625
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.42237776517868
# Epoch 56 :
# Testing accuracy: 74.86953735351562 %; detection rate: 73.68594360351562; false alarm: 23.946868896484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.4842492043972
# Epoch 57 :
# Testing accuracy: 74.92695617675781 %; detection rate: 72.828125; false alarm: 22.974212646484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.47102570533752
# Epoch 58 :
# Testing accuracy: 74.90898895263672 %; detection rate: 72.04609680175781; false alarm: 22.228118896484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.42658016085625
# Epoch 59 :
# Testing accuracy: 74.9058609008789 %; detection rate: 72.94062805175781; false alarm: 23.12890625
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.40695849061012
# Epoch 60 :
# Testing accuracy: 74.830078125 %; detection rate: 73.70938110351562; false alarm: 24.049217224121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.44410473108292
# Epoch 61 :
# Testing accuracy: 74.9156265258789 %; detection rate: 72.3515625; false alarm: 22.520309448242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.40230029821396
# Epoch 62 :
# Testing accuracy: 74.87031555175781 %; detection rate: 72.9507827758789; false alarm: 23.21015167236328
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.44154474139214
# Epoch 63 :
# Testing accuracy: 74.84648895263672 %; detection rate: 73.09844207763672; false alarm: 23.40546417236328
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.4034824371338
# Epoch 64 :
# Testing accuracy: 74.9000015258789 %; detection rate: 72.21015930175781; false alarm: 22.41015625
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.4034832417965
# Epoch 65 :
# Testing accuracy: 74.88516235351562 %; detection rate: 73.20156860351562; false alarm: 23.431243896484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.36778488755226
# Epoch 66 :
# Testing accuracy: 74.8921890258789 %; detection rate: 73.30313110351562; false alarm: 23.51874542236328
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.4006918668747
# Epoch 67 :
# Testing accuracy: 74.90742492675781 %; detection rate: 73.484375; false alarm: 23.669525146484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.38801515102386
# Epoch 68 :
# Testing accuracy: 74.89961242675781 %; detection rate: 72.36797332763672; false alarm: 22.568748474121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.42291328310966
# Epoch 69 :
# Testing accuracy: 74.8609390258789 %; detection rate: 72.75078582763672; false alarm: 23.028900146484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.37547025084496
# Epoch 70 :
# Testing accuracy: 74.86797332763672 %; detection rate: 72.6328125; false alarm: 22.896873474121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.33391451835632
# Epoch 71 :
# Testing accuracy: 74.82695770263672 %; detection rate: 74.3046875; false alarm: 24.650779724121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.38031136989594
# Epoch 72 :
# Testing accuracy: 74.87539672851562 %; detection rate: 73.65469360351562; false alarm: 23.903900146484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.3916930258274
# Epoch 73 :
# Testing accuracy: 74.87422180175781 %; detection rate: 72.31094360351562; false alarm: 22.5625
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.3691203892231
# Epoch 74 :
# Testing accuracy: 74.85039520263672 %; detection rate: 73.1500015258789; false alarm: 23.44921875
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.372205555439
# Epoch 75 :
# Testing accuracy: 74.87226867675781 %; detection rate: 73.19062805175781; false alarm: 23.446090698242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.35704827308655
# Epoch 76 :
# Testing accuracy: 74.85391235351562 %; detection rate: 74.01406860351562; false alarm: 24.306243896484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.3599036335945
# Epoch 77 :
# Testing accuracy: 74.90703582763672 %; detection rate: 72.87109375; false alarm: 23.057029724121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.40539702773094
# Epoch 78 :
# Testing accuracy: 74.84883117675781 %; detection rate: 74.08984375; false alarm: 24.392181396484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.3884313106537
# Epoch 79 :
# Testing accuracy: 74.81367492675781 %; detection rate: 73.31953430175781; false alarm: 23.692184448242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.379385471344
# Epoch 80 :
# Testing accuracy: 74.89336395263672 %; detection rate: 72.9468765258789; false alarm: 23.16015625
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.2650327384472
# Epoch 81 :
# Testing accuracy: 74.86640930175781 %; detection rate: 72.27422332763672; false alarm: 22.541404724121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.34951123595238
# Epoch 82 :
# Testing accuracy: 74.83633422851562 %; detection rate: 72.79296875; false alarm: 23.12030792236328
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.39228716492653
# Epoch 83 :
# Testing accuracy: 74.873046875 %; detection rate: 72.95000457763672; false alarm: 23.203903198242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.30798637866974
# Epoch 84 :
# Testing accuracy: 74.8746109008789 %; detection rate: 72.94844055175781; false alarm: 23.19921875
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.31187918782234
# Epoch 85 :
# Testing accuracy: 74.89336395263672 %; detection rate: 73.32344055175781; false alarm: 23.536712646484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.2897151708603
# Epoch 86 :
# Testing accuracy: 74.888671875 %; detection rate: 73.3359375; false alarm: 23.55859375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.31342229247093
# Epoch 87 :
# Testing accuracy: 74.8394546508789 %; detection rate: 73.75; false alarm: 24.071090698242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.300911039114
# Epoch 88 :
# Testing accuracy: 74.85000610351562 %; detection rate: 72.75625610351562; false alarm: 23.056243896484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.30439239740372
# Epoch 89 :
# Testing accuracy: 74.8843765258789 %; detection rate: 73.71406555175781; false alarm: 23.9453125
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.29786604642868
# Epoch 90 :
# Testing accuracy: 74.8785171508789 %; detection rate: 71.93047332763672; false alarm: 22.173431396484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.2889902293682
# Epoch 91 :
# Testing accuracy: 74.87187957763672 %; detection rate: 73.2632827758789; false alarm: 23.51953125
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.30275750160217
# Epoch 92 :
# Testing accuracy: 74.91094207763672 %; detection rate: 72.7632827758789; false alarm: 22.94140625
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.32515969872475
# Epoch 93 :
# Testing accuracy: 74.89102172851562 %; detection rate: 72.9375; false alarm: 23.15546417236328
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.2785717844963
# Epoch 94 :
# Testing accuracy: 74.8882827758789 %; detection rate: 72.7578125; false alarm: 22.981246948242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.29030919075012
# Epoch 95 :
# Testing accuracy: 74.93476867675781 %; detection rate: 72.26484680175781; false alarm: 22.395309448242188
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.2598734498024
# Epoch 96 :
# Testing accuracy: 74.85664367675781 %; detection rate: 72.73281860351562; false alarm: 23.01953125
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.2524533867836
# Epoch 97 :
# Testing accuracy: 74.87930297851562 %; detection rate: 72.83125305175781; false alarm: 23.072654724121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.3134991824627
# Epoch 98 :
# Testing accuracy: 74.88711547851562 %; detection rate: 72.67422485351562; false alarm: 22.899993896484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.2983989417553
# Epoch 99 :
# Testing accuracy: 74.85195922851562 %; detection rate: 72.87734985351562; false alarm: 23.173431396484375
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.25487214326859
# Epoch 100 :
# Testing accuracy: 74.8531265258789 %; detection rate: 72.1773452758789; false alarm: 22.471092224121094
# Learning rate: 0.0003
# Max accuracy: 74.93476867675781 %; training loss: , 137.26005232334137
# Statics saved to excel: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/VaryingVolum/2400_221212_19_41/convergSNR-6.xlsx
# Time spent for running100epochs 0:16:39.143411
# Testing accuracy: 59.71992492675781 %; detection rate: 99.86250305175781; false alarm: 80.42265319824219
# Testing accuracy: 59.99922180175781 %; detection rate: 99.84609985351562; false alarm: 79.84765625
# Testing accuracy: 60.25039291381836 %; detection rate: 99.8257827758789; false alarm: 79.32499694824219
# Testing accuracy: 60.55000305175781 %; detection rate: 99.81328582763672; false alarm: 78.7132797241211
# Testing accuracy: 60.839454650878906 %; detection rate: 99.7945327758789; false alarm: 78.1156234741211
# Testing accuracy: 61.152347564697266 %; detection rate: 99.76875305175781; false alarm: 77.46406555175781
# Testing accuracy: 61.452735900878906 %; detection rate: 99.75312805175781; false alarm: 76.84765625
# Testing accuracy: 61.75312805175781 %; detection rate: 99.72266387939453; false alarm: 76.2164077758789
# Testing accuracy: 62.083595275878906 %; detection rate: 99.70000457763672; false alarm: 75.5328140258789
# Testing accuracy: 62.39570617675781 %; detection rate: 99.65547180175781; false alarm: 74.86405944824219
# Testing accuracy: 62.679298400878906 %; detection rate: 99.6226577758789; false alarm: 74.2640609741211
# Testing accuracy: 62.983985900878906 %; detection rate: 99.58047485351562; false alarm: 73.61250305175781
# Testing accuracy: 63.32148742675781 %; detection rate: 99.55547332763672; false alarm: 72.9124984741211
# Testing accuracy: 63.628910064697266 %; detection rate: 99.50469207763672; false alarm: 72.24687194824219
# Testing accuracy: 63.92304992675781 %; detection rate: 99.45313262939453; false alarm: 71.60702514648438
# Testing accuracy: 64.22344207763672 %; detection rate: 99.39844512939453; false alarm: 70.9515609741211
# Testing accuracy: 64.53242492675781 %; detection rate: 99.34687805175781; false alarm: 70.28202819824219
# Testing accuracy: 64.82421875 %; detection rate: 99.28984832763672; false alarm: 69.64140319824219
# Testing accuracy: 65.09883117675781 %; detection rate: 99.22266387939453; false alarm: 69.02499389648438
# Testing accuracy: 65.41328430175781 %; detection rate: 99.16641235351562; false alarm: 68.33984375
# Testing accuracy: 65.7203140258789 %; detection rate: 99.0914077758789; false alarm: 67.6507797241211
# Testing accuracy: 66.02734375 %; detection rate: 99.01094055175781; false alarm: 66.95625305175781
# Testing accuracy: 66.29219055175781 %; detection rate: 98.9312515258789; false alarm: 66.34687805175781
# Testing accuracy: 66.55859375 %; detection rate: 98.83203887939453; false alarm: 65.71484375
# Testing accuracy: 66.783203125 %; detection rate: 98.74531555175781; false alarm: 65.17890930175781
# Testing accuracy: 67.04531860351562 %; detection rate: 98.6734390258789; false alarm: 64.58280944824219
# Testing accuracy: 67.3082046508789 %; detection rate: 98.6031265258789; false alarm: 63.986717224121094
# Testing accuracy: 67.552734375 %; detection rate: 98.50703430175781; false alarm: 63.40156173706055
# Testing accuracy: 67.7906265258789 %; detection rate: 98.39375305175781; false alarm: 62.8125
# Testing accuracy: 68.015625 %; detection rate: 98.26797485351562; false alarm: 62.236717224121094
# Testing accuracy: 68.24453735351562 %; detection rate: 98.15156555175781; false alarm: 61.662498474121094
# Testing accuracy: 68.4683609008789 %; detection rate: 98.0171890258789; false alarm: 61.080467224121094
# Testing accuracy: 68.69453430175781 %; detection rate: 97.88906860351562; false alarm: 60.5
# Testing accuracy: 68.90664672851562 %; detection rate: 97.73281860351562; false alarm: 59.91952896118164
# Testing accuracy: 69.1324234008789 %; detection rate: 97.52656555175781; false alarm: 59.261714935302734
# Testing accuracy: 69.3843765258789 %; detection rate: 97.28594207763672; false alarm: 58.51718521118164
# Testing accuracy: 69.6734390258789 %; detection rate: 97.00625610351562; false alarm: 57.65937423706055
# Testing accuracy: 69.97344207763672 %; detection rate: 96.66328430175781; false alarm: 56.71640396118164
# Testing accuracy: 70.3062515258789 %; detection rate: 96.2320327758789; false alarm: 55.619529724121094
# Testing accuracy: 70.63320922851562 %; detection rate: 95.60391235351562; false alarm: 54.33749771118164
# Testing accuracy: 71.0503921508789 %; detection rate: 94.85938262939453; false alarm: 52.75859069824219
# Testing accuracy: 71.51445770263672 %; detection rate: 93.90156555175781; false alarm: 50.87265396118164
# Testing accuracy: 72.07109832763672 %; detection rate: 92.84844207763672; false alarm: 48.70624923706055
# Testing accuracy: 72.5503921508789 %; detection rate: 91.30313110351562; false alarm: 46.20234298706055
# Testing accuracy: 73.08711242675781 %; detection rate: 89.51797485351562; false alarm: 43.343746185302734
# Testing accuracy: 73.6167984008789 %; detection rate: 87.34062957763672; false alarm: 40.10702896118164
# Testing accuracy: 74.0503921508789 %; detection rate: 84.82891082763672; false alarm: 36.72812271118164
# Testing accuracy: 74.44414520263672 %; detection rate: 82.08125305175781; false alarm: 33.192962646484375
# Testing accuracy: 74.69766235351562 %; detection rate: 79.0; false alarm: 29.60468292236328
# Testing accuracy: 74.85391235351562 %; detection rate: 75.66796875; false alarm: 25.96015167236328
# Testing accuracy: 74.93476867675781 %; detection rate: 72.3257827758789; false alarm: 22.45624542236328
# Testing accuracy: 74.77774047851562 %; detection rate: 68.86250305175781; false alarm: 19.307029724121094
# Testing accuracy: 74.580078125 %; detection rate: 65.62109375; false alarm: 16.46092987060547
# Testing accuracy: 74.29609680175781 %; detection rate: 62.38359832763672; false alarm: 13.791404724121094
# Testing accuracy: 73.92227172851562 %; detection rate: 59.36406707763672; false alarm: 11.519523620605469
# Testing accuracy: 73.44140625 %; detection rate: 56.484378814697266; false alarm: 9.601554870605469
# Testing accuracy: 72.99140930175781 %; detection rate: 54.001564025878906; false alarm: 8.018745422363281
# Testing accuracy: 72.43476867675781 %; detection rate: 51.47343826293945; false alarm: 6.603904724121094
# Testing accuracy: 71.9683609008789 %; detection rate: 49.41093826293945; false alarm: 5.474212646484375
# Testing accuracy: 71.56953430175781 %; detection rate: 47.638282775878906; false alarm: 4.499214172363281
# Testing accuracy: 71.1421890258789 %; detection rate: 46.048439025878906; false alarm: 3.7640609741210938
# Testing accuracy: 70.755859375 %; detection rate: 44.71171951293945; false alarm: 3.1999969482421875
# Testing accuracy: 70.38711547851562 %; detection rate: 43.517189025878906; false alarm: 2.7429656982421875
# Testing accuracy: 70.06562805175781 %; detection rate: 42.51250076293945; false alarm: 2.3812484741210938
# Testing accuracy: 69.76992797851562 %; detection rate: 41.59609603881836; false alarm: 2.056243896484375
# Testing accuracy: 69.52969360351562 %; detection rate: 40.82500076293945; false alarm: 1.7656173706054688
# Testing accuracy: 69.29219055175781 %; detection rate: 40.15703201293945; false alarm: 1.5726547241210938
# Testing accuracy: 69.0777359008789 %; detection rate: 39.56172180175781; false alarm: 1.4062423706054688
# Testing accuracy: 68.85664367675781 %; detection rate: 38.98515701293945; false alarm: 1.2718734741210938
# Testing accuracy: 68.64297485351562 %; detection rate: 38.4609375; false alarm: 1.1749954223632812
# Testing accuracy: 68.43633270263672 %; detection rate: 37.946876525878906; false alarm: 1.0742111206054688
# Testing accuracy: 68.26094055175781 %; detection rate: 37.497657775878906; false alarm: 0.9757766723632812
# Testing accuracy: 68.06680297851562 %; detection rate: 37.0390625; false alarm: 0.9054641723632812
# Testing accuracy: 67.88516235351562 %; detection rate: 36.61953353881836; false alarm: 0.849212646484375
# Testing accuracy: 67.70742797851562 %; detection rate: 36.18359375; false alarm: 0.7687454223632812
# Testing accuracy: 67.54141235351562 %; detection rate: 35.7890625; false alarm: 0.7062454223632812
# Testing accuracy: 67.33086395263672 %; detection rate: 35.329689025878906; false alarm: 0.6679611206054688
# Testing accuracy: 67.13359832763672 %; detection rate: 34.892189025878906; false alarm: 0.6249923706054688
# Testing accuracy: 66.95000457763672 %; detection rate: 34.47343826293945; false alarm: 0.5734329223632812
# Testing accuracy: 66.77188110351562 %; detection rate: 34.06328201293945; false alarm: 0.5195236206054688
# Testing accuracy: 66.56875610351562 %; detection rate: 33.61796951293945; false alarm: 0.48046112060546875
# Testing accuracy: 66.3648452758789 %; detection rate: 33.177345275878906; false alarm: 0.44765472412109375
# Testing accuracy: 66.17695617675781 %; detection rate: 32.76875305175781; false alarm: 0.4148406982421875
# Testing accuracy: 65.98906707763672 %; detection rate: 32.35546875; false alarm: 0.37734222412109375
# Testing accuracy: 65.78008270263672 %; detection rate: 31.910158157348633; false alarm: 0.34999847412109375
# Testing accuracy: 65.58672332763672 %; detection rate: 31.49453353881836; false alarm: 0.3210906982421875
# Testing accuracy: 65.3671875 %; detection rate: 31.031251907348633; false alarm: 0.29686737060546875
# Testing accuracy: 65.15547180175781 %; detection rate: 30.58437728881836; false alarm: 0.27342987060546875
# Testing accuracy: 64.94023895263672 %; detection rate: 30.140626907348633; false alarm: 0.26015472412109375
# Testing accuracy: 64.74453735351562 %; detection rate: 29.727344512939453; false alarm: 0.23827362060546875
# Testing accuracy: 64.55078125 %; detection rate: 29.317970275878906; false alarm: 0.216400146484375
# Testing accuracy: 64.359375 %; detection rate: 28.917970657348633; false alarm: 0.19921112060546875
# Testing accuracy: 64.1441421508789 %; detection rate: 28.466407775878906; false alarm: 0.17812347412109375
# Testing accuracy: 63.92890930175781 %; detection rate: 28.024219512939453; false alarm: 0.16640472412109375
# Testing accuracy: 63.69375228881836 %; detection rate: 27.542970657348633; false alarm: 0.15546417236328125
# Testing accuracy: 63.45977020263672 %; detection rate: 27.058595657348633; false alarm: 0.13906097412109375
# Testing accuracy: 63.24531555175781 %; detection rate: 26.61640739440918; false alarm: 0.1257781982421875
# Testing accuracy: 63.03203582763672 %; detection rate: 26.183595657348633; false alarm: 0.11952972412109375
# Testing accuracy: 62.824222564697266 %; detection rate: 25.760156631469727; false alarm: 0.11171722412109375
# Testing accuracy: 62.60430145263672 %; detection rate: 25.310937881469727; false alarm: 0.1023406982421875
# Statics saved to excel: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/VaryingVolum/2400_221212_19_41/ROC_SNR-6.xlsx
# ROC in Lists saved to: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/VaryingVolum/2400_221212_19_41/WrTOct26ROC.pth
# Dataset description: cleanPSD64.pth, SNR-6dB, 10bands, 6PUs, 64pts/band.
# 3.279839277267456 2.5345261096954346
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register count_softmax() for <class 'torch.nn.modules.activation.Softmax'>.
# macs are :
#  49312.0
# params are :
#  6362.0
# model watermark 221212_20_01
# Model saved to dir:
#  /content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/VaryingVolum/2400_221212_20_01/WrTOct26_SNR-6vol2400.pth
# Epoch 1 :
# Testing accuracy: 49.720314025878906 %; detection rate: 29.625001907348633; false alarm: 30.184371948242188
# Learning rate: 0.0003
# Max accuracy: 49.720314145088196 %; training loss: , 187.68599498271942
# Epoch 2 :
# Testing accuracy: 71.10781860351562 %; detection rate: 69.8062515258789; false alarm: 27.590621948242188
# Learning rate: 0.0003
# Max accuracy: 71.10781669616699 %; training loss: , 150.28699538111687
# Epoch 3 :
# Testing accuracy: 73.19180297851562 %; detection rate: 70.8179702758789; false alarm: 24.434371948242188
# Learning rate: 0.0003
# Max accuracy: 73.19179773330688 %; training loss: , 142.55803522467613
# Epoch 4 :
# Testing accuracy: 74.1796875 %; detection rate: 73.51875305175781; false alarm: 25.15937042236328
# Learning rate: 0.0003
# Max accuracy: 74.17969107627869 %; training loss: , 140.45740163326263
# Epoch 5 :
# Testing accuracy: 74.66875457763672 %; detection rate: 75.3453140258789; false alarm: 26.0078125
# Learning rate: 0.0003
# Max accuracy: 74.66875314712524 %; training loss: , 139.43706706166267
# Epoch 6 :
# Testing accuracy: 74.83984375 %; detection rate: 73.89688110351562; false alarm: 24.217185974121094
# Learning rate: 0.0003
# Max accuracy: 74.839848279953 %; training loss: , 139.05287492275238
# Epoch 7 :
# Testing accuracy: 74.90156555175781 %; detection rate: 73.38594055175781; false alarm: 23.582809448242188
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 138.7771813571453
# Epoch 8 :
# Testing accuracy: 74.85195922851562 %; detection rate: 72.921875; false alarm: 23.21796417236328
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 138.59262818098068
# Epoch 9 :
# Testing accuracy: 74.83828735351562 %; detection rate: 73.27969360351562; false alarm: 23.603118896484375
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 138.4046277999878
# Epoch 10 :
# Testing accuracy: 74.85781860351562 %; detection rate: 72.2437515258789; false alarm: 22.528121948242188
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 138.2590635418892
# Epoch 11 :
# Testing accuracy: 74.859375 %; detection rate: 73.27188110351562; false alarm: 23.553123474121094
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 138.15081191062927
# Epoch 12 :
# Testing accuracy: 74.89570617675781 %; detection rate: 73.8531265258789; false alarm: 24.06171417236328
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 138.10384327173233
# Epoch 13 :
# Testing accuracy: 74.88008117675781 %; detection rate: 73.359375; false alarm: 23.599212646484375
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 138.02763512730598
# Epoch 14 :
# Testing accuracy: 74.81094360351562 %; detection rate: 74.70156860351562; false alarm: 25.079681396484375
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 137.9987585246563
# Epoch 15 :
# Testing accuracy: 74.87969207763672 %; detection rate: 73.08984375; false alarm: 23.330467224121094
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 137.96736001968384
# Epoch 16 :
# Testing accuracy: 74.869140625 %; detection rate: 73.09453582763672; false alarm: 23.356246948242188
# Learning rate: 0.0003
# Max accuracy: 74.90156888961792 %; training loss: , 137.924298286438
# Epoch 17 :
# Testing accuracy: 74.92695617675781 %; detection rate: 73.78750610351562; false alarm: 23.93359375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.87223970890045
# Epoch 18 :
# Testing accuracy: 74.85469055175781 %; detection rate: 74.27656555175781; false alarm: 24.567184448242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.85374030470848
# Epoch 19 :
# Testing accuracy: 74.90625 %; detection rate: 74.3179702758789; false alarm: 24.505462646484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.80933728814125
# Epoch 20 :
# Testing accuracy: 74.861328125 %; detection rate: 72.04141235351562; false alarm: 22.318748474121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.81681528687477
# Epoch 21 :
# Testing accuracy: 74.86406707763672 %; detection rate: 72.5796890258789; false alarm: 22.8515625
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.79549181461334
# Epoch 22 :
# Testing accuracy: 74.91796875 %; detection rate: 72.06484985351562; false alarm: 22.228904724121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.76405841112137
# Epoch 23 :
# Testing accuracy: 74.91523742675781 %; detection rate: 72.10859680175781; false alarm: 22.278121948242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.71019661426544
# Epoch 24 :
# Testing accuracy: 74.86797332763672 %; detection rate: 73.2125015258789; false alarm: 23.4765625
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.6913222670555
# Epoch 25 :
# Testing accuracy: 74.912109375 %; detection rate: 72.20781707763672; false alarm: 22.383590698242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.6699277162552
# Epoch 26 :
# Testing accuracy: 74.861328125 %; detection rate: 74.86563110351562; false alarm: 25.142967224121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.67642059922218
# Epoch 27 :
# Testing accuracy: 74.86953735351562 %; detection rate: 74.50390625; false alarm: 24.76483917236328
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.65410310029984
# Epoch 28 :
# Testing accuracy: 74.90234375 %; detection rate: 72.43047332763672; false alarm: 22.625778198242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.65029296278954
# Epoch 29 :
# Testing accuracy: 74.85391235351562 %; detection rate: 72.74922180175781; false alarm: 23.041404724121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.63291504979134
# Epoch 30 :
# Testing accuracy: 74.88906860351562 %; detection rate: 73.73359680175781; false alarm: 23.955467224121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.62888890504837
# Epoch 31 :
# Testing accuracy: 74.8648452758789 %; detection rate: 74.02656555175781; false alarm: 24.296875
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.59464374184608
# Epoch 32 :
# Testing accuracy: 74.9214859008789 %; detection rate: 73.38750457763672; false alarm: 23.544525146484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.54484528303146
# Epoch 33 :
# Testing accuracy: 74.87187957763672 %; detection rate: 72.87734985351562; false alarm: 23.133590698242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.59177646040916
# Epoch 34 :
# Testing accuracy: 74.84492492675781 %; detection rate: 72.76406860351562; false alarm: 23.07421875
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.58504584431648
# Epoch 35 :
# Testing accuracy: 74.88164520263672 %; detection rate: 72.60234832763672; false alarm: 22.83905792236328
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.55626982450485
# Epoch 36 :
# Testing accuracy: 74.8609390258789 %; detection rate: 73.09062957763672; false alarm: 23.368743896484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.57081094384193
# Epoch 37 :
# Testing accuracy: 74.90156555175781 %; detection rate: 73.35391235351562; false alarm: 23.55078125
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.5248429775238
# Epoch 38 :
# Testing accuracy: 74.8921890258789 %; detection rate: 72.82344055175781; false alarm: 23.0390625
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.5097926557064
# Epoch 39 :
# Testing accuracy: 74.875 %; detection rate: 73.140625; false alarm: 23.390625
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.520077586174
# Epoch 40 :
# Testing accuracy: 74.8785171508789 %; detection rate: 72.56172180175781; false alarm: 22.8046875
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.5275755226612
# Epoch 41 :
# Testing accuracy: 74.82421875 %; detection rate: 74.44844055175781; false alarm: 24.79999542236328
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.5654966533184
# Epoch 42 :
# Testing accuracy: 74.8394546508789 %; detection rate: 74.3203125; false alarm: 24.641403198242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.54253748059273
# Epoch 43 :
# Testing accuracy: 74.88750457763672 %; detection rate: 73.36640930175781; false alarm: 23.591400146484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.5076555609703
# Epoch 44 :
# Testing accuracy: 74.87344360351562 %; detection rate: 72.55390930175781; false alarm: 22.807029724121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.50740736722946
# Epoch 45 :
# Testing accuracy: 74.82266235351562 %; detection rate: 74.16250610351562; false alarm: 24.517181396484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.45086124539375
# Epoch 46 :
# Testing accuracy: 74.90469360351562 %; detection rate: 73.07891082763672; false alarm: 23.26953125
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.46086385846138
# Epoch 47 :
# Testing accuracy: 74.912109375 %; detection rate: 72.22187805175781; false alarm: 22.39765167236328
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.46784895658493
# Epoch 48 :
# Testing accuracy: 74.87890625 %; detection rate: 72.73125457763672; false alarm: 22.973434448242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.50617119669914
# Epoch 49 :
# Testing accuracy: 74.87344360351562 %; detection rate: 73.0367202758789; false alarm: 23.289840698242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.4518506526947
# Epoch 50 :
# Testing accuracy: 74.9117202758789 %; detection rate: 72.32421875; false alarm: 22.500778198242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.4121630191803
# Epoch 51 :
# Testing accuracy: 74.83906555175781 %; detection rate: 73.06640625; false alarm: 23.388275146484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.44708719849586
# Epoch 52 :
# Testing accuracy: 74.8902359008789 %; detection rate: 73.08515930175781; false alarm: 23.3046875
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.45266526937485
# Epoch 53 :
# Testing accuracy: 74.90859985351562 %; detection rate: 72.8179702758789; false alarm: 23.000778198242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.41582083702087
# Epoch 54 :
# Testing accuracy: 74.8433609008789 %; detection rate: 73.69375610351562; false alarm: 24.00702667236328
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.40838050842285
# Epoch 55 :
# Testing accuracy: 74.859375 %; detection rate: 73.46875; false alarm: 23.75
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.45436295866966
# Epoch 56 :
# Testing accuracy: 74.8687515258789 %; detection rate: 73.33125305175781; false alarm: 23.59375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.3907975256443
# Epoch 57 :
# Testing accuracy: 74.8570327758789 %; detection rate: 73.63203430175781; false alarm: 23.91796875
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.38322487473488
# Epoch 58 :
# Testing accuracy: 74.86992645263672 %; detection rate: 73.48828125; false alarm: 23.748435974121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.4098477959633
# Epoch 59 :
# Testing accuracy: 74.91484832763672 %; detection rate: 72.5703125; false alarm: 22.740623474121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.37990522384644
# Epoch 60 :
# Testing accuracy: 74.8667984008789 %; detection rate: 72.203125; false alarm: 22.469528198242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.38351002335548
# Epoch 61 :
# Testing accuracy: 74.85234832763672 %; detection rate: 73.2984390258789; false alarm: 23.59375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.39765411615372
# Epoch 62 :
# Testing accuracy: 74.88125610351562 %; detection rate: 72.65312957763672; false alarm: 22.890625
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.4277478158474
# Epoch 63 :
# Testing accuracy: 74.88594055175781 %; detection rate: 72.98828125; false alarm: 23.216400146484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.38524621725082
# Epoch 64 :
# Testing accuracy: 74.8671875 %; detection rate: 72.71562957763672; false alarm: 22.981246948242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.38931596279144
# Epoch 65 :
# Testing accuracy: 74.84805297851562 %; detection rate: 73.54922485351562; false alarm: 23.853118896484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.3707018494606
# Epoch 66 :
# Testing accuracy: 74.869140625 %; detection rate: 72.8062515258789; false alarm: 23.067962646484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.33190086483955
# Epoch 67 :
# Testing accuracy: 74.89570617675781 %; detection rate: 72.45781707763672; false alarm: 22.666404724121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.3582440316677
# Epoch 68 :
# Testing accuracy: 74.912109375 %; detection rate: 72.8414077758789; false alarm: 23.017181396484375
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.3485687971115
# Epoch 69 :
# Testing accuracy: 74.85000610351562 %; detection rate: 73.11250305175781; false alarm: 23.412498474121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.31240782141685
# Epoch 70 :
# Testing accuracy: 74.88516235351562 %; detection rate: 73.12812805175781; false alarm: 23.357810974121094
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.33766302466393
# Epoch 71 :
# Testing accuracy: 74.86836242675781 %; detection rate: 72.7945327758789; false alarm: 23.05780792236328
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.32805588841438
# Epoch 72 :
# Testing accuracy: 74.89179992675781 %; detection rate: 73.22187805175781; false alarm: 23.438278198242188
# Learning rate: 0.0003
# Max accuracy: 74.92695450782776 %; training loss: , 137.35173299908638
# Epoch 73 :
# ...
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.87251323461533
# Epoch 91 :
# Testing accuracy: 74.93008422851562 %; detection rate: 73.69219207763672; false alarm: 23.83203125
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.84643158316612
# Epoch 92 :
# Testing accuracy: 74.9351577758789 %; detection rate: 73.41015625; false alarm: 23.539840698242188
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.89376658201218
# Epoch 93 :
# Testing accuracy: 74.94062805175781 %; detection rate: 72.85234832763672; false alarm: 22.971092224121094
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.85949316620827
# Epoch 94 :
# Testing accuracy: 74.91836547851562 %; detection rate: 72.35859680175781; false alarm: 22.521873474121094
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.87206026911736
# Epoch 95 :
# Testing accuracy: 74.92578125 %; detection rate: 72.64531707763672; false alarm: 22.793746948242188
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.84946382045746
# Epoch 96 :
# Testing accuracy: 74.90625 %; detection rate: 72.9375; false alarm: 23.125
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.85616827011108
# Epoch 97 :
# Testing accuracy: 74.923828125 %; detection rate: 73.17500305175781; false alarm: 23.32733917236328
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.820904225111
# Epoch 98 :
# Testing accuracy: 74.96367645263672 %; detection rate: 72.2085952758789; false alarm: 22.28125
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.9047532081604
# Epoch 99 :
# Testing accuracy: 74.96015930175781 %; detection rate: 73.0796890258789; false alarm: 23.15937042236328
# Learning rate: 0.0003
# Max accuracy: 74.96367692947388 %; training loss: , 227.8064824938774
# Epoch 100 :
# Testing accuracy: 74.97109985351562 %; detection rate: 73.2320327758789; false alarm: 23.289840698242188
# Learning rate: 0.0003
# Max accuracy: 74.97109770774841 %; training loss: , 227.8384181857109
# Statics saved to excel: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/VaryingVolum/4000_221212_21_27/convergSNR-6.xlsx
# Time spent for running100epochs 0:31:27.695287
# Testing accuracy: 59.64101791381836 %; detection rate: 99.87110137939453; false alarm: 80.58906555175781
# Testing accuracy: 59.931644439697266 %; detection rate: 99.8609390258789; false alarm: 79.9976577758789
# Testing accuracy: 60.21133041381836 %; detection rate: 99.85157012939453; false alarm: 79.42890930175781
# Testing accuracy: 60.492191314697266 %; detection rate: 99.83438110351562; false alarm: 78.8499984741211
# Testing accuracy: 60.83125305175781 %; detection rate: 99.8140640258789; false alarm: 78.15156555175781
# Testing accuracy: 61.126564025878906 %; detection rate: 99.79219055175781; false alarm: 77.5390625
# Testing accuracy: 61.44805145263672 %; detection rate: 99.76563262939453; false alarm: 76.8695297241211
# Testing accuracy: 61.75234603881836 %; detection rate: 99.74844360351562; false alarm: 76.2437515258789
# Testing accuracy: 62.06484603881836 %; detection rate: 99.71953582763672; false alarm: 75.58984375
# Testing accuracy: 62.382423400878906 %; detection rate: 99.6890640258789; false alarm: 74.9242172241211
# Testing accuracy: 62.704689025878906 %; detection rate: 99.65235137939453; false alarm: 74.24296569824219
# Testing accuracy: 63.00898742675781 %; detection rate: 99.61563110351562; false alarm: 73.59765625
# Testing accuracy: 63.30703353881836 %; detection rate: 99.57344055175781; false alarm: 72.9593734741211
# Testing accuracy: 63.685157775878906 %; detection rate: 99.5328140258789; false alarm: 72.1624984741211
# Testing accuracy: 64.04336547851562 %; detection rate: 99.47187805175781; false alarm: 71.3851547241211
# Testing accuracy: 64.35664367675781 %; detection rate: 99.4117202758789; false alarm: 70.69844055175781
# Testing accuracy: 64.6539077758789 %; detection rate: 99.35078430175781; false alarm: 70.04296875
# Testing accuracy: 64.92890930175781 %; detection rate: 99.29766082763672; false alarm: 69.4398422241211
# Testing accuracy: 65.2281265258789 %; detection rate: 99.21797180175781; false alarm: 68.76171875
# Testing accuracy: 65.55390930175781 %; detection rate: 99.1460952758789; false alarm: 68.03828430175781
# Testing accuracy: 65.8531265258789 %; detection rate: 99.07032012939453; false alarm: 67.36405944824219
# Testing accuracy: 66.13594055175781 %; detection rate: 98.99610137939453; false alarm: 66.72421264648438
# Testing accuracy: 66.41484832763672 %; detection rate: 98.91407012939453; false alarm: 66.0843734741211
# Testing accuracy: 66.68437957763672 %; detection rate: 98.83203887939453; false alarm: 65.4632797241211
# Testing accuracy: 66.96172332763672 %; detection rate: 98.75312805175781; false alarm: 64.82968139648438
# Testing accuracy: 67.20429992675781 %; detection rate: 98.65312957763672; false alarm: 64.2445297241211
# Testing accuracy: 67.4644546508789 %; detection rate: 98.55390930175781; false alarm: 63.625
# Testing accuracy: 67.7007827758789 %; detection rate: 98.45703887939453; false alarm: 63.05546569824219
# Testing accuracy: 67.89492797851562 %; detection rate: 98.33906555175781; false alarm: 62.549217224121094
# Testing accuracy: 68.12812805175781 %; detection rate: 98.21485137939453; false alarm: 61.95859146118164
# Testing accuracy: 68.34687805175781 %; detection rate: 98.08281707763672; false alarm: 61.389060974121094
# Testing accuracy: 68.56680297851562 %; detection rate: 97.98125457763672; false alarm: 60.84765625
# Testing accuracy: 68.7734375 %; detection rate: 97.80547332763672; false alarm: 60.25859069824219
# Testing accuracy: 69.00234985351562 %; detection rate: 97.66875457763672; false alarm: 59.664058685302734
# Testing accuracy: 69.21601867675781 %; detection rate: 97.50078582763672; false alarm: 59.068748474121094
# Testing accuracy: 69.44609832763672 %; detection rate: 97.26875305175781; false alarm: 58.37656021118164
# Testing accuracy: 69.72383117675781 %; detection rate: 97.02265930175781; false alarm: 57.57499694824219
# Testing accuracy: 69.9761734008789 %; detection rate: 96.71172332763672; false alarm: 56.75937271118164
# Testing accuracy: 70.25312805175781 %; detection rate: 96.29219055175781; false alarm: 55.78593444824219
# Testing accuracy: 70.6109390258789 %; detection rate: 95.7437515258789; false alarm: 54.521873474121094
# Testing accuracy: 70.97265625 %; detection rate: 95.0601577758789; false alarm: 53.11484146118164
# Testing accuracy: 71.46406555175781 %; detection rate: 94.2593765258789; false alarm: 51.33124923706055
# Testing accuracy: 71.92890930175781 %; detection rate: 93.1539077758789; false alarm: 49.29609298706055
# Testing accuracy: 72.45234680175781 %; detection rate: 91.80547332763672; false alarm: 46.900779724121094
# Testing accuracy: 72.96524047851562 %; detection rate: 90.11719512939453; false alarm: 44.18671798706055
# Testing accuracy: 73.47148895263672 %; detection rate: 88.09062957763672; false alarm: 41.14765167236328
# Testing accuracy: 73.94805145263672 %; detection rate: 85.71328735351562; false alarm: 37.81718444824219
# Testing accuracy: 74.3375015258789 %; detection rate: 82.9507827758789; false alarm: 34.275779724121094
# Testing accuracy: 74.62149047851562 %; detection rate: 79.78125; false alarm: 30.53827667236328
# Testing accuracy: 74.83047485351562 %; detection rate: 76.546875; false alarm: 26.88593292236328
# Testing accuracy: 74.97109985351562 %; detection rate: 73.2320327758789; false alarm: 23.289840698242188
# Testing accuracy: 74.85781860351562 %; detection rate: 69.7398452758789; false alarm: 20.024215698242188
# Testing accuracy: 74.634765625 %; detection rate: 66.33906555175781; false alarm: 17.06952667236328
# Testing accuracy: 74.35859680175781 %; detection rate: 63.00234603881836; false alarm: 14.285148620605469
# Testing accuracy: 73.98281860351562 %; detection rate: 59.83125305175781; false alarm: 11.865623474121094
# Testing accuracy: 73.53555297851562 %; detection rate: 56.875003814697266; false alarm: 9.803901672363281
# Testing accuracy: 73.04804992675781 %; detection rate: 54.15547180175781; false alarm: 8.059371948242188
# Testing accuracy: 72.5171890258789 %; detection rate: 51.66719055175781; false alarm: 6.632804870605469
# Testing accuracy: 72.0367202758789 %; detection rate: 49.46015930175781; false alarm: 5.386711120605469
# Testing accuracy: 71.54296875 %; detection rate: 47.59062576293945; false alarm: 4.5046844482421875
# Testing accuracy: 71.14688110351562 %; detection rate: 45.988285064697266; false alarm: 3.6945266723632812
# Testing accuracy: 70.68867492675781 %; detection rate: 44.51015853881836; false alarm: 3.1328048706054688
# Testing accuracy: 70.30742645263672 %; detection rate: 43.25859451293945; false alarm: 2.6437454223632812
# Testing accuracy: 69.99883270263672 %; detection rate: 42.212501525878906; false alarm: 2.2148361206054688
# Testing accuracy: 69.69062805175781 %; detection rate: 41.286720275878906; false alarm: 1.9054641723632812
# Testing accuracy: 69.38711547851562 %; detection rate: 40.39687728881836; false alarm: 1.622650146484375
# Testing accuracy: 69.1382827758789 %; detection rate: 39.685157775878906; false alarm: 1.4085922241210938
# Testing accuracy: 68.9058609008789 %; detection rate: 39.0703125; false alarm: 1.2585906982421875
# Testing accuracy: 68.65351867675781 %; detection rate: 38.44921875; false alarm: 1.142181396484375
# Testing accuracy: 68.44609832763672 %; detection rate: 37.92578125; false alarm: 1.0335922241210938
# Testing accuracy: 68.24336242675781 %; detection rate: 37.43593978881836; false alarm: 0.9492111206054688
# Testing accuracy: 68.05390930175781 %; detection rate: 36.970314025878906; false alarm: 0.8624954223632812
# Testing accuracy: 67.833984375 %; detection rate: 36.4609375; false alarm: 0.7929611206054688
# Testing accuracy: 67.60781860351562 %; detection rate: 35.95156478881836; false alarm: 0.735931396484375
# Testing accuracy: 67.42656707763672 %; detection rate: 35.5390625; false alarm: 0.6859359741210938
# Testing accuracy: 67.23867797851562 %; detection rate: 35.11172103881836; false alarm: 0.634368896484375
# Testing accuracy: 67.03164672851562 %; detection rate: 34.63515853881836; false alarm: 0.571868896484375
# Testing accuracy: 66.84062957763672 %; detection rate: 34.20625305175781; false alarm: 0.524993896484375
# Testing accuracy: 66.640625 %; detection rate: 33.77656555175781; false alarm: 0.49530792236328125
# Testing accuracy: 66.43399047851562 %; detection rate: 33.30937576293945; false alarm: 0.44139862060546875
# Testing accuracy: 66.22891235351562 %; detection rate: 32.8515625; false alarm: 0.39374542236328125
# Testing accuracy: 65.99883270263672 %; detection rate: 32.3671875; false alarm: 0.36952972412109375
# Testing accuracy: 65.79727172851562 %; detection rate: 31.931251525878906; false alarm: 0.3367156982421875
# Testing accuracy: 65.6207046508789 %; detection rate: 31.55390739440918; false alarm: 0.31249237060546875
# Testing accuracy: 65.427734375 %; detection rate: 31.14765739440918; false alarm: 0.29218292236328125
# Testing accuracy: 65.216796875 %; detection rate: 30.70625114440918; false alarm: 0.27265167236328125
# Testing accuracy: 64.990234375 %; detection rate: 30.242969512939453; false alarm: 0.2624969482421875
# Testing accuracy: 64.7730484008789 %; detection rate: 29.79140853881836; false alarm: 0.24530792236328125
# Testing accuracy: 64.57929992675781 %; detection rate: 29.38593864440918; false alarm: 0.2273406982421875
# Testing accuracy: 64.35195922851562 %; detection rate: 28.914844512939453; false alarm: 0.21092987060546875
# Testing accuracy: 64.13164520263672 %; detection rate: 28.453126907348633; false alarm: 0.18984222412109375
# Testing accuracy: 63.91445541381836 %; detection rate: 28.00703239440918; false alarm: 0.17812347412109375
# Testing accuracy: 63.707035064697266 %; detection rate: 27.571876525878906; false alarm: 0.157806396484375
# Testing accuracy: 63.46172332763672 %; detection rate: 27.067188262939453; false alarm: 0.14374542236328125
# Testing accuracy: 63.246097564697266 %; detection rate: 26.629688262939453; false alarm: 0.1374969482421875
# Testing accuracy: 63.01055145263672 %; detection rate: 26.144533157348633; false alarm: 0.12343597412109375
# Testing accuracy: 62.80742645263672 %; detection rate: 25.724220275878906; false alarm: 0.10936737060546875
# Testing accuracy: 62.62773895263672 %; detection rate: 25.353126525878906; false alarm: 0.09764862060546875
# Testing accuracy: 62.42031478881836 %; detection rate: 24.92500114440918; false alarm: 0.08437347412109375
# Testing accuracy: 62.22578430175781 %; detection rate: 24.528125762939453; false alarm: 0.07656097412109375
# Statics saved to excel: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/VaryingVolum/4000_221212_21_27/ROC_SNR-6.xlsx
# ROC in Lists saved to: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/VaryingVolum/4000_221212_21_27/WrTOct26ROC.pth
# Dataset description: cleanPSD64.pth, SNR-6dB, 10bands, 6PUs, 64pts/band.
# 3.2792792320251465 2.5346224308013916
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register count_softmax() for <class 'torch.nn.modules.activation.Softmax'>.
# macs are :
#  49312.0
# params are :
#  6362.0
# model watermark 221212_22_06
# Model saved to dir:
#  /content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/VaryingVolum/4000_221212_22_06/WrTOct26_SNR-6vol4000.pth
# Epoch 1 :
# Testing accuracy: 50.02031326293945 %; detection rate: 43.55312728881836; false alarm: 43.51249694824219
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-79d77e9115f2> in <module>
#     225
#     226     #uniform the y axis, label SNR on title
# --> 227     v, training_loss = train(v, train_loader, epoch=i, volum=volum)# Test first and train then version
#     228     print(f'Max accuracy: {100 * max_acc} %; training loss: , {training_loss}')
#     229
#
# <ipython-input-5-79d77e9115f2> in train(model, trainloader, epoch, volum)
#      50       outputs = model(inputs)
#      51       loss = criterion(outputs, labels)
# ---> 52       loss.backward()
#      53       optimizer.step()
#      54       # print statistics
#
# /usr/local/lib/python3.8/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# /usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     # some Python versions print out the first line of a multi-line function
#     196     # calls in the traceback and some print out the last line
# --> 197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/signal_handling.py in handler(signum, frame)
#      64         # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65         # Python can still get and update the process status successfully.
# ---> 66         _error_if_any_worker_fails()
#      67         if previous_handler is not None:
#      68             assert callable(previous_handler)
#
# RuntimeError: DataLoader worker (pid 77493) is killed by signal: Killed.

# %%
#load and test model form disk/drive
v_param = torch.load('/content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/221116_20_30/WrTOct26_SNR-6vol800.pth')
v.load_state_dict(v_param)
acc_ = test(v, test_loader)
print(acc_)

# %%
from google.colab import runtime
runtime.unassign()

# %%
# v = WrT(
#     spectra_size = WrT_var['spectra_size'],
#     patch_size = WrT_var['patch_size'],
#     num_bands = WrT_var['num_bands'],
#     dim = WrT_var['dim'], # 512
#     depth = WrT_var['depth'], #6
#     heads = WrT_var['heads'], #8
#     mlp_dim = WrT_var['mlp_dim'], #1024
#     dropout = WrT_var['dropout'],
#     dim_head = WrT_var['dim_head'],
#     emb_dropout = WrT_var['emb_dropout'],
#     pool = WrT_var['pool'],
# ).to(device)

# #not good with depth: 3 heads 4 dim 64 mlpdim 128
# criterion = nn.BCEWithLogitsLoss()

# # v = AlexNet1D(num_classes = 10).to(device)
# summary(v, (1,1,640))

# %%
# #long word 320
# v = WrT(
#     spectra_size = (1, datas_tr[0].size(0)),
#     patch_size = (1,320),
#     num_bands = labels_te[0].size(0),
#     dim = 64, # 512
#     depth = 3, #6
#     heads = 4, #8
#     mlp_dim = 128, #1024
#     dropout = 0.1,
#     dim_head = 16,
#     emb_dropout = 0.1,
#     pool = 'mean'
# ).to(device)

# #not good with depth: 3 heads 4 dim 64 mlpdim 128
# criterion = nn.BCEWithLogitsLoss()

# %%
# #short word 64
# v = WrT(
#     spectra_size = (1, datas_tr[0].size(0)),
#     patch_size = (1,64),
#     num_bands = labels_te[0].size(0),
#     dim = 8, # 512
#     depth = 1, #6
#     heads = 1, #8
#     mlp_dim = 16, #1024
#     dropout = 0.1,
#     dim_head = 8,
#     emb_dropout = 0.1,
#     pool = 'mean'
# ).to(device)

# #not good with depth: 3 heads 4 dim 64 mlpdim 128
# criterion = nn.BCEWithLogitsLoss()

# %%
# finish_tim=datetime.datetime.now(TMZ)
# print('Time spent for running'+str(nepoch)+'epochs',finish_tim - now)

# %%
# plt.title("ROC of " +type(v).__name__+ " method in SNR="+str(SNR)+"dB")
# l3, = plt.plot(pfa3, pd3, color='green', label='Transformer')
# plt.legend(loc='lower right')
# plt.show()

# %%
# ROC_dict=torch.load('')  #load another result for reference
# plt.title("ROC of several methods at SNR="+str(SNR)+'dB')
# # l1, = plt.plot(pfa, pd, color='blue',label='EnergyDetection1')
# l2, = plt.plot(ROC_dict['pfa'], ROC_dict['pd'], color='red', label='Transformer')
# l3, = plt.plot(pfa3, pd3, color='green', label='Transformer')
# plt.legend(loc='lower right')
# plt.show()
