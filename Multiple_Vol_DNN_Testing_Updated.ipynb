# %% [markdown]
# 2022 Oct 20th, continue for model saving and acc list saving excel.
# Figure statics are saved to dir of model param
#
# 2022 Sep 27th, trimed and refined. For wideband DNNs by default.
#
# 2022 Sep 12th, Adding DIY data normalization. Considering CNN with less FC layers, adding Dropout for DNNs
#
# 2022 July 15th, Transformer can't use Weight_decay!
#
# 2022 July 14th, editted for Prelim model structure selection.
#
# 2022 July 1st, editted for Prelim Results plotting.

# %%
#Jan 17 Redo with DeepSenseHalf
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install einops #maynot be needed every time restarting runtime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 1.7 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.6.0

# %%
# !pip install thop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from thop) (1.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->thop) (4.4.0)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %%
import torch
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time
import heapq
import os
import math
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import sys
from copy import deepcopy
import random
import collections
from scipy import signal
from torchsummary import summary 
from drive.MyDrive.Wireless_Transformer.PSDshow import imshow
from drive.MyDrive.Wireless_Transformer.wrt import WrT # customized design of Wireless Transformer
from drive.MyDrive.Wireless_Transformer.AlexNet1D import AlexNet1D #import DIY DNN models
from drive.MyDrive.Wireless_Transformer.AlexNet1D import AlexNet1DConv
from drive.MyDrive.Wireless_Transformer.AlexNet1D import TutorialCNN
from drive.MyDrive.Wireless_Transformer.AlexNet1D import TutorialCNN2
from drive.MyDrive.Wireless_Transformer.AlexNet1D import TutorialCNN3
from drive.MyDrive.Wireless_Transformer.AlexNet1D import TutorialCNN4
from drive.MyDrive.Wireless_Transformer.AlexNet1D import TutorialCNN5
from drive.MyDrive.Wireless_Transformer.AlexNet1D import SmallMLP
from drive.MyDrive.Wireless_Transformer.AlexNet1D import BiggerMLP1
from drive.MyDrive.Wireless_Transformer.AlexNet1D import DeepSense
from drive.MyDrive.Wireless_Transformer.AlexNet1D import DeepSenseHalf
from drive.MyDrive.Wireless_Transformer.AlexNet1D import DeepSenseQuarter
from drive.MyDrive.Wireless_Transformer.AlexNet1D import DeepSenseEighth
from drive.MyDrive.Wireless_Transformer.AlexNet1D import DeepSenseSmall

from torch.utils.data import Dataset, DataLoader
from pytz import timezone
TMZ = timezone('EST')
device = torch.device("cuda")
import datetime
import shutil
from thop import profile
# torch.manual_seed(0)

# %%
'''Sep12 version, DIY normalization'''
class ToyDatasetMaker(Dataset):
    "Toy version that wrap data/label tensor list into pytorch dataset"
    def __init__(self, data_list, label_list, transformFunc=transforms.Compose([ ]), norm_config=(1,1) ):
        """
        db: a list of input signal tensors, 
        label_list: a list of data labels, align with elements in db.
        """
        self.datasets = data_list
        self.label_list = label_list
        self.transformFunc = transformFunc
        self.norm_config = norm_config
    def __getitem__(self, i):
        img = self.datasets[i]
        img = self.transformFunc(img)
        img = (img-self.norm_config[0])/self.norm_config[1] # added for normalizing non-image
        class_label = self.label_list[i]
        return img, class_label

    def __len__(self):
        return len(self.label_list)
def adjust_learning_rate(optimizer, epoch):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    epoch_inter = 20
#     print("Decrease learning rate every %d epoch by %2f" %(epoch_inter, des))
    #lr = 0.01 * (des ** (epoch // epoch_inter))
    bs = 1 #0.4 #0.2
    lr = 0.0005 * bs ** (epoch/epoch_inter)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

def train(model, trainloader, epoch):
# tune weight_decay for different DNNs
  if isinstance(model, WrT): 
    weight_decay=0.000  #weight_decay=0.0005 for Alex
  if isinstance(model, TutorialCNN): 
    weight_decay=0.0005 #
  if isinstance(model, TutorialCNN2): 
    weight_decay=0.0005 #
  if isinstance(model, AlexNet1D): 
    weight_decay=0.0015 #
  if isinstance(model, AlexNet1DConv): 
    weight_decay=0.000 # .0001 has overfit
  if isinstance(model, DeepSenseEighth):
    weight_decay=0.0
  else: #for other CNN or MLP
    weight_decay=0.00 #
  # optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=weight_decay)
  optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=weight_decay )


  adjust_learning_rate(optimizer, epoch)
  running_loss = 0.0
  model.train()
  for i, data in enumerate(trainloader, 0):
      inputs, labels = data
      inputs = Variable(inputs.view(-1,1,1,datas_tr[0].size(0)).to(device)) #640
      labels = Variable(labels.to(device))
      optimizer.zero_grad()# zero the parameter gradients
      outputs = model(inputs)
      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
  print('Learning rate:', optimizer.param_groups[0]['lr'])
  return model, running_loss

def test(model, testloader, thresh = 0):
  total = 0 #sum of occupation and emptiness
  total_ocp = 0 #occupied bands
  total_emp = 0 #empty bands
  correct = 0
  correct_ocp = 0
  correct_emp = 0
  model.eval()
  with torch.no_grad():
    for data in testloader:
        inputs, labels = data
        inputs = Variable(inputs.view(-1,1,1,datas_tr[0].size(0) ).to(device)) #10bands=>640, 8bands=>512
        labels = Variable(labels.to(device)) 
        total_batch = float( torch.tensor(labels.size()).prod() ) 
        total += total_batch
        total_ocp += float(labels.sum())  #occupied bands
        total_emp += float(total_batch - labels.sum())  #empty bands
        outputs = ( model(inputs)> thresh ).bool()
        labels = labels.bool()
        correct_ocp += (outputs * labels).sum() 
        correct_emp += (~outputs * ~labels).sum()
        correct = correct_ocp + correct_emp
        if (outputs * labels).sum()+(~outputs * ~labels).sum() != (~(outputs^labels)) .sum():
          print('wrong!', (outputs * labels).sum()+(~outputs * ~labels).sum(),'!=', (~(outputs^labels)).sum())

  print(f'Testing accuracy: {100 * correct/total} %; detection rate: {100*correct_ocp/total_ocp}; false alarm: {100-100*correct_emp/total_emp}')
  return (correct/total, correct_ocp/total_ocp, correct_emp/total_emp) 

def setDir(filepath):
  # if directory not exist, create. if directory already exist, empty it.
  if not os.path.exists(filepath):
    os.makedirs(filepath)
  else:
    print('Directory already exists')
    shutil.rmtree(filepath, ignore_errors = True)
    os.mkdir(filepath)


for volum in [20, 50, 100, 200, 400, 800, 1600, 2400, 3200, 4000]: #[20, 50, 100, 200, 400, 800, 1600, 2400]: #[20, 50, 100, 200, 400, 800, 1600, 2400, 3200, 4000]:#[200, 200] : #[800, 800, 1600]: # #[4000]:  #[1600]: #[400,200,100]: 
  SNR = -6
  # volum = 3200 #4000 #samples per ocp pattern
  address1 =  '/content/drive/MyDrive/Wireless_Transformer/LeftRightIndep/' #LeftRightIndep version

  #use data under /RefinedNewData/ for submission
  # name1 = 'T_8b3P1sig_SNR'+str(SNR)+'.pth' #data of PU with the same sig
  name1 = 'T_10b5P5sig_SNR'+str(SNR)+'vol'+str(volum)+'.pth' #10bands, 5PUs, 5 kinds of sig, training & testing together
  # data_dict = torch.load(address1 + name1) # uncomment when volum is real
  #==================================Data_path_override======================================
  # data_dict = torch.load( '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/221024_13_53/221024_13_53Data_SNR-5vol4000.pth')
  # datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/221027_21_14/221027_21_14Data_SNR-5vol4000.pth'
  # datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/221030_17_33/221030_17_33Data_SNR-5vol4000.pth'
  datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/221030_21_21/221030_21_21Data_SNR'+str(SNR)+'vol4000.pth'
  # datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/unbonded/221116_19_42/221116_19_42Data_SNR-6vol250.pth'
  # datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/varyingsize/221116_17_02/221116_17_02Data_SNR-6vol3200.pth'

  data_dict1 = torch.load( datadir )# use complete training data

  print('Dataset description:', data_dict1['Description'] )
  datas_te = data_dict1['testing data list']
  labels_te = data_dict1['testing label list']
  # datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/varyingsize/221117_21_33/221117_21_33Data_SNR-6vol'+str(volum)+'.pth' #for 100-400
  # datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/varyingsize/221116_17_02/221116_17_02Data_SNR-6vol'+str(volum)+'.pth' #for 800-3200
  datadir = '/content/drive/MyDrive/Wireless_Transformer/RefinedNewData/varyingsize/Data_SNR-6vol'+str(volum)+'.pth'

  data_dict1 = torch.load( datadir )
  datas_tr = data_dict1['training data list']
  labels_tr = data_dict1['training label list']

  num_bands = labels_te[0]
  #Calculate dataset mean and std 
  datas_all = datas_tr+datas_te
  data_tens =torch.cat(datas_all,dim=0) #data tensor for calculating mean&std, similar result if using training_data alone
  (data_mean, data_std) = ( torch.mean(data_tens).item(), torch.std(data_tens).item() )
  print(data_mean, data_std)

  trainset= ToyDatasetMaker(datas_tr, labels_tr, norm_config=(data_mean, data_std) )
  testset= ToyDatasetMaker(datas_te, labels_te, norm_config=(data_mean, data_std) )
  train_loader = DataLoader(trainset, batch_size=min(500,volum), shuffle=True, num_workers=12, pin_memory=True)
  test_loader = DataLoader(testset, batch_size=1000, shuffle=False, num_workers=16, pin_memory=True)

  # v = DeepSense(num_classes = labels_te[0].size(0)).to(device) 

  # v = DeepSenseEighth(num_classes = labels_te[0].size(0)).to(device)
  v = DeepSenseHalf(num_classes = labels_te[0].size(0)).to(device)

  criterion = nn.BCEWithLogitsLoss()

  summary(v, (1,640)) #show model details
  macs, params = profile(v.to('cpu'), inputs =(torch.randn(1, 640), )) #model on CPU
  print('macs are :\n',macs)
  print('params are :\n',params)
  # break
  v= v.to(device)


  nepoch = 100 #200
  acc_list = []
  acc_ocp_list = []
  fa_list = []
  # plt.title("Global Model ACC of the proposed method")
  max_acc = 0.
  now=datetime.datetime.now(TMZ) #time watermark
  time_watermark = now.strftime('%y%m%d_%H_%M')
  print('model watermark',time_watermark)
  address_model = '/content/drive/MyDrive/Wireless_Transformer/Saved_Models/'+type(v).__name__+'/VaryVolum/'+str(volum)+'_'+time_watermark+'/' #root dir for saved models
  #child dir nbamed by time_watermark
  setDir(address_model) # if dir not exist, create. if dir already exist, empty it.
  name1 = type(v).__name__ +'_SNR'+str(SNR)+'vol'+str(volum)+'.pth'
  print('Model saved to dir:\n', address_model+name1)
  txt=open(address_model+'Datasetdir.txt',"w").write(datadir)#save dataset dir (dataset version)
  for i in range(nepoch):
    print('Epoch', i+1,':')      
    acc_ = test(v, test_loader)
      
    if acc_[0].cpu().item() > max_acc:
      max_acc = acc_[0].cpu().item()
      torch.save(v.state_dict(), address_model+name1)

    acc_list.append( acc_[0].cpu().item())
    acc_ocp_list.append(acc_[1].cpu().item())
    fa_list.append((1-acc_[2]).cpu().item())

    v, training_loss = train(v, train_loader, epoch=i)# Test first and train then version
    print(f'Max accuracy: {100 * max_acc} %; training loss: , {training_loss}') #print('training loss: ', training_loss)

  # axis = list( range(nepoch) )
  plt.figure(1,figsize=(5, 4), dpi=80)
  l1, = plt.plot( acc_list, color='blue',label='Avg Acc/band')
  l2, = plt.plot( fa_list, color='red', label='FA')
  l3, = plt.plot( acc_ocp_list, color='black', label='Acc 4 busy')
  plt.legend(loc='lower right')
  plt.title('SNR='+str(SNR)+'dB,'+ type(v).__name__+ ' Model ACC reaches %.3f %%' %  (100*max(acc_list))  )
  plt.show()

  plt.figure(2,figsize=(5, 4), dpi=80)
  l1, = plt.plot( acc_list, color='blue',label='Avg Acc/band')
  # l2, = plt.plot( fa_list, color='red', label='FA')
  # l3, = plt.plot( acc_ocp_list, color='black', label='Acc 4 busy')
  plt.legend(loc='lower right')
  plt.title('SNR='+str(SNR)+'dB,'+ type(v).__name__+ ' Model ACC reaches %.3f %%' %  (100*max(acc_list))  )
  plt.show()

  df1 = pd.DataFrame()
  # df1['acc_old'] = xx
  df1['Accuracy'] = acc_list
  df1['FA'] = fa_list
  df1['PD'] = acc_ocp_list

  rootaddr = address_model 

  with pd.ExcelWriter(rootaddr + "converg"+"SNR"+str(SNR)+".xlsx", mode='w') as writer:  #mode was 'a'
    df1.to_excel(writer, sheet_name=type(v).__name__)
  print('statics saved to excel:', rootaddr + "converg"+"SNR"+str(SNR)+".xlsx")
  #uniform the y axis, label SNR on title
  finish_tim=datetime.datetime.now(TMZ)
  print('Time spent for running'+str(nepoch)+'epochs',finish_tim - now)

  '''ROC module of current AlexNet model, saved in pd2 and pfa2'''
  pd2= []
  pfa2 = []

  v.load_state_dict(torch.load(address_model+name1))

  for thresh_val in [ (i-50)/12.5 for i in range(100)]: 
    #[i*0.9999/100 for i in list(range(1,100))]
    # in [(1-i/50)*5e-8+1e-10 for i in list(range(50))]
      CNNoutput = test(v, test_loader, thresh=thresh_val) #
      #testnets( net_list, class_dir, tol_test_loader, thresh_sig = thresh_val )
      pd2.append(CNNoutput[1].to(torch.device('cpu')).item())
      pfa2.append(1-CNNoutput[2].to(torch.device('cpu')).item())

  plt.title("ROC of " +type(v).__name__+ " method in SNR="+str(SNR)+"dB")
  l2, = plt.plot(pfa2, pd2, color='green', label='Transformer')
  plt.legend(loc='lower right')
  plt.show()

  dfroc = pd.DataFrame() # save statics to excel
  # df1['acc_old'] = xx
  dfroc['PD'] = pd2
  dfroc['PFA'] = pfa2
  with pd.ExcelWriter(address_model + "ROC_SNR"+str(SNR)+".xlsx", mode='w') as writer:  #mode was 'a'
    dfroc.to_excel(writer, sheet_name=type(v).__name__)
  print('ROC in Excel saved to:', address_model + "ROC_SNR"+str(SNR)+".xlsx")

  ROC_dict = {
      'pd':pd2,
      'pfa':pfa2,
  }
  torch.save(ROC_dict, address_model+type(v).__name__+'ROC.pth')
  print('ROC in Lists saved to:', address_model+type(v).__name__+'ROC.pth')
# Out:
# Dataset description: cleanPSD64.pth, SNR-6dB, 10bands, 6PUs, 64pts/band.
# 3.2790606021881104 2.534287452697754
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1               [-1, 8, 640]              48
#             Conv1d-2               [-1, 8, 640]             328
#             Conv1d-3              [-1, 16, 320]             656
#             Conv1d-4              [-1, 16, 320]           1,296
#             Linear-5                   [-1, 10]          25,610
# ================================================================
# Total params: 27,938
# Trainable params: 27,938
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.16
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.27
# ----------------------------------------------------------------
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv1d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# macs are :
#  870400.0
# params are :
#  27938.0
# model watermark 230117_22_11
# Model saved to dir:
#  /content/drive/MyDrive/Wireless_Transformer/Saved_Models/DeepSenseHalf/VaryVolum/20_230117_22_11/DeepSenseHalf_SNR-6vol20.pth
# Epoch 1 :
# Testing accuracy: 49.70039367675781 %; detection rate: 50.70625305175781; false alarm: 51.30546569824219
# Learning rate: 0.0005
# Max accuracy: 49.70039427280426 %; training loss: , 44.339277505874634
# Epoch 2 :
# Testing accuracy: 53.41250228881836 %; detection rate: 69.38906860351562; false alarm: 62.56406021118164
# Learning rate: 0.0005
# Max accuracy: 53.4125030040741 %; training loss: , 42.839831709861755
# Epoch 3 :
# Testing accuracy: 66.404296875 %; detection rate: 61.87578582763672; false alarm: 29.067184448242188
# Learning rate: 0.0005
# Max accuracy: 66.40430092811584 %; training loss: , 36.471995800733566
# Epoch 4 :
# Testing accuracy: 67.69140625 %; detection rate: 73.8203125; false alarm: 38.437496185302734
# Learning rate: 0.0005
# Max accuracy: 67.69140958786011 %; training loss: , 33.36645358800888
# Epoch 5 :
# Testing accuracy: 67.5523452758789 %; detection rate: 54.55000305175781; false alarm: 19.44530487060547
# Learning rate: 0.0005
# Max accuracy: 67.69140958786011 %; training loss: , 32.42020705342293
# Epoch 6 :
# Testing accuracy: 69.11953735351562 %; detection rate: 69.0210952758789; false alarm: 30.782028198242188
# Learning rate: 0.0005
# Max accuracy: 69.11953687667847 %; training loss: , 31.77570191025734
# Epoch 7 :
# Testing accuracy: 69.2359390258789 %; detection rate: 71.50703430175781; false alarm: 33.03515625
# Learning rate: 0.0005
# Max accuracy: 69.23593878746033 %; training loss: , 31.137715876102448
# Epoch 8 :
# Testing accuracy: 69.55586242675781 %; detection rate: 67.51016235351562; false alarm: 28.3984375
# Learning rate: 0.0005
# Max accuracy: 69.55586075782776 %; training loss: , 31.167533367872238
# Epoch 9 :
# Testing accuracy: 69.572265625 %; detection rate: 69.45234680175781; false alarm: 30.30780792236328
# Learning rate: 0.0005
# Max accuracy: 69.57226991653442 %; training loss: , 30.203735440969467
# Epoch 10 :
# Testing accuracy: 69.7300796508789 %; detection rate: 69.32734680175781; false alarm: 29.8671875
# Learning rate: 0.0005
# Max accuracy: 69.73007917404175 %; training loss: , 30.276144117116928
# Epoch 11 :
# Testing accuracy: 69.5484390258789 %; detection rate: 67.21406555175781; false alarm: 28.1171875
# Learning rate: 0.0005
# Max accuracy: 69.73007917404175 %; training loss: , 29.518392592668533
# Epoch 12 :
# Testing accuracy: 69.24258422851562 %; detection rate: 61.542972564697266; false alarm: 23.05780792236328
# Learning rate: 0.0005
# Max accuracy: 69.73007917404175 %; training loss: , 29.143330305814743
# Epoch 13 :
# Testing accuracy: 69.74649047851562 %; detection rate: 67.9039077758789; false alarm: 28.410934448242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 29.029479056596756
# Epoch 14 :
# Testing accuracy: 69.62890625 %; detection rate: 72.5796890258789; false alarm: 33.321868896484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 28.68411275744438
# Epoch 15 :
# Testing accuracy: 69.4765625 %; detection rate: 71.69140625; false alarm: 32.73828125
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 28.205356776714325
# Epoch 16 :
# Testing accuracy: 69.34805297851562 %; detection rate: 75.00390625; false alarm: 36.30780792236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 28.370936512947083
# Epoch 17 :
# Testing accuracy: 69.46914672851562 %; detection rate: 74.2265625; false alarm: 35.28827667236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 28.078270941972733
# Epoch 18 :
# Testing accuracy: 69.27461242675781 %; detection rate: 74.41875457763672; false alarm: 35.869529724121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 27.30466601252556
# Epoch 19 :
# Testing accuracy: 69.1402359008789 %; detection rate: 68.08203125; false alarm: 29.801559448242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 27.10059666633606
# Epoch 20 :
# Testing accuracy: 69.3824234008789 %; detection rate: 68.01641082763672; false alarm: 29.251556396484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 26.851392835378647
# Epoch 21 :
# Testing accuracy: 69.47383117675781 %; detection rate: 72.296875; false alarm: 33.349212646484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 26.61643099784851
# Epoch 22 :
# Testing accuracy: 69.125 %; detection rate: 63.17500305175781; false alarm: 24.92499542236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 26.44035914540291
# Epoch 23 :
# Testing accuracy: 69.60977172851562 %; detection rate: 65.56172180175781; false alarm: 26.342185974121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 26.347099900245667
# Epoch 24 :
# Testing accuracy: 69.16484832763672 %; detection rate: 65.56172180175781; false alarm: 27.232025146484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 25.848482131958008
# Epoch 25 :
# Testing accuracy: 69.19023895263672 %; detection rate: 68.12109375; false alarm: 29.740623474121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 25.56593483686447
# Epoch 26 :
# Testing accuracy: 69.15078735351562 %; detection rate: 65.35234832763672; false alarm: 27.05078125
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 25.40415593981743
# Epoch 27 :
# Testing accuracy: 69.1890640258789 %; detection rate: 68.2046890258789; false alarm: 29.826560974121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 25.01681688427925
# Epoch 28 :
# Testing accuracy: 69.17500305175781 %; detection rate: 67.30000305175781; false alarm: 28.949996948242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 24.805485427379608
# Epoch 29 :
# Testing accuracy: 68.861328125 %; detection rate: 64.36797332763672; false alarm: 26.645309448242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 24.93296128511429
# Epoch 30 :
# Testing accuracy: 68.8433609008789 %; detection rate: 72.02031707763672; false alarm: 34.333587646484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 24.336133420467377
# Epoch 31 :
# Testing accuracy: 69.19609832763672 %; detection rate: 67.0390625; false alarm: 28.646873474121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 24.282741397619247
# Epoch 32 :
# Testing accuracy: 68.96015930175781 %; detection rate: 65.18437957763672; false alarm: 27.264060974121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 23.741301119327545
# Epoch 33 :
# Testing accuracy: 68.74844360351562 %; detection rate: 71.13203430175781; false alarm: 33.635154724121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 24.115938633680344
# Epoch 34 :
# Testing accuracy: 68.7847671508789 %; detection rate: 65.48672485351562; false alarm: 27.91718292236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 23.758681684732437
# Epoch 35 :
# Testing accuracy: 68.8785171508789 %; detection rate: 68.63516235351562; false alarm: 30.87812042236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 23.388826161623
# Epoch 36 :
# Testing accuracy: 68.69414520263672 %; detection rate: 63.95547103881836; false alarm: 26.567184448242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 23.04830425977707
# Epoch 37 :
# Testing accuracy: 68.85586547851562 %; detection rate: 70.24609375; false alarm: 32.53437042236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 22.92625543475151
# Epoch 38 :
# Testing accuracy: 68.56367492675781 %; detection rate: 64.65312957763672; false alarm: 27.525779724121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 23.208207949995995
# Epoch 39 :
# Testing accuracy: 68.41914367675781 %; detection rate: 69.953125; false alarm: 33.114837646484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 22.41731631755829
# Epoch 40 :
# Testing accuracy: 68.56367492675781 %; detection rate: 67.96172332763672; false alarm: 30.834373474121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 22.80438244342804
# Epoch 41 :
# Testing accuracy: 68.5269546508789 %; detection rate: 69.86016082763672; false alarm: 32.806243896484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 22.583113193511963
# Epoch 42 :
# Testing accuracy: 68.4375 %; detection rate: 65.60781860351562; false alarm: 28.732810974121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 21.920451924204826
# Epoch 43 :
# Testing accuracy: 68.26445770263672 %; detection rate: 67.578125; false alarm: 31.049217224121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 21.918278068304062
# Epoch 44 :
# Testing accuracy: 68.3804702758789 %; detection rate: 70.45625305175781; false alarm: 33.6953125
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 21.2775516808033
# Epoch 45 :
# Testing accuracy: 68.3765640258789 %; detection rate: 67.6578140258789; false alarm: 30.904685974121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 21.69294399023056
# Epoch 46 :
# Testing accuracy: 68.4375 %; detection rate: 68.5484390258789; false alarm: 31.673431396484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 21.108009949326515
# Epoch 47 :
# Testing accuracy: 68.21992492675781 %; detection rate: 72.3296890258789; false alarm: 35.88983917236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 20.818683952093124
# Epoch 48 :
# Testing accuracy: 68.30078125 %; detection rate: 65.9585952758789; false alarm: 29.357025146484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 21.444062128663063
# Epoch 49 :
# Testing accuracy: 68.13984680175781 %; detection rate: 66.62578582763672; false alarm: 30.346092224121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 20.486752539873123
# Epoch 50 :
# Testing accuracy: 68.3046875 %; detection rate: 66.46797180175781; false alarm: 29.85858917236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 20.767527893185616
# Epoch 51 :
# Testing accuracy: 68.2261734008789 %; detection rate: 66.2203140258789; false alarm: 29.767967224121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 20.392993539571762
# Epoch 52 :
# Testing accuracy: 68.1734390258789 %; detection rate: 68.93828582763672; false alarm: 32.591400146484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 20.049216955900192
# Epoch 53 :
# Testing accuracy: 68.14961242675781 %; detection rate: 64.41796875; false alarm: 28.118743896484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 20.600762501358986
# Epoch 54 :
# Testing accuracy: 68.10859680175781 %; detection rate: 68.8921890258789; false alarm: 32.67499542236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 20.098531633615494
# Epoch 55 :
# Testing accuracy: 68.099609375 %; detection rate: 66.03203582763672; false alarm: 29.832809448242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 20.283026471734047
# Epoch 56 :
# Testing accuracy: 68.0992202758789 %; detection rate: 70.64765930175781; false alarm: 34.44921875
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 19.975270703434944
# Epoch 57 :
# Testing accuracy: 67.93359375 %; detection rate: 66.1460952758789; false alarm: 30.278900146484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 20.03765194118023
# Epoch 58 :
# Testing accuracy: 68.36211395263672 %; detection rate: 68.8062515258789; false alarm: 32.08203125
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 19.15249338746071
# Epoch 59 :
# Testing accuracy: 67.90703582763672 %; detection rate: 65.7281265258789; false alarm: 29.9140625
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 19.219869628548622
# Epoch 60 :
# Testing accuracy: 68.06680297851562 %; detection rate: 69.47734832763672; false alarm: 33.34375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 19.36036255955696
# Epoch 61 :
# Testing accuracy: 68.26055145263672 %; detection rate: 69.11250305175781; false alarm: 32.591400146484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.484423846006393
# Epoch 62 :
# Testing accuracy: 68.28828430175781 %; detection rate: 68.7359390258789; false alarm: 32.15937042236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 19.3568424731493
# Epoch 63 :
# Testing accuracy: 68.16641235351562 %; detection rate: 72.04766082763672; false alarm: 35.71484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.76242646574974
# Epoch 64 :
# Testing accuracy: 68.10234832763672 %; detection rate: 63.76797103881836; false alarm: 27.563278198242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.468231037259102
# Epoch 65 :
# Testing accuracy: 67.94805145263672 %; detection rate: 66.2359390258789; false alarm: 30.33984375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.691891372203827
# Epoch 66 :
# Testing accuracy: 68.13984680175781 %; detection rate: 65.30547332763672; false alarm: 29.025779724121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.57796521484852
# Epoch 67 :
# Testing accuracy: 67.611328125 %; detection rate: 67.69140625; false alarm: 32.46875
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.359536170959473
# Epoch 68 :
# Testing accuracy: 68.0601577758789 %; detection rate: 67.25703430175781; false alarm: 31.13671875
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.68162801861763
# Epoch 69 :
# Testing accuracy: 68.1953125 %; detection rate: 65.96484375; false alarm: 29.57421875
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.53189903497696
# Epoch 70 :
# Testing accuracy: 67.92890930175781 %; detection rate: 66.22109985351562; false alarm: 30.36328125
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.82610024511814
# Epoch 71 :
# Testing accuracy: 68.11836242675781 %; detection rate: 70.2789077758789; false alarm: 34.04218292236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 17.798577934503555
# Epoch 72 :
# Testing accuracy: 68.1500015258789 %; detection rate: 69.1460952758789; false alarm: 32.846092224121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 18.38627815246582
# Epoch 73 :
# Testing accuracy: 67.9957046508789 %; detection rate: 70.1031265258789; false alarm: 34.111717224121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 17.673474609851837
# Epoch 74 :
# Testing accuracy: 67.826171875 %; detection rate: 68.20391082763672; false alarm: 32.55155944824219
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 17.350887462496758
# Epoch 75 :
# Testing accuracy: 67.9976577758789 %; detection rate: 64.81328582763672; false alarm: 28.817962646484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 17.440049171447754
# Epoch 76 :
# Testing accuracy: 67.78437805175781 %; detection rate: 64.43672180175781; false alarm: 28.867965698242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 17.336014956235886
# Epoch 77 :
# Testing accuracy: 68.05742645263672 %; detection rate: 66.25625610351562; false alarm: 30.141403198242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.869046345353127
# Epoch 78 :
# Testing accuracy: 68.13164520263672 %; detection rate: 70.85859680175781; false alarm: 34.595306396484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 17.25436083972454
# Epoch 79 :
# Testing accuracy: 67.72187805175781 %; detection rate: 70.18594360351562; false alarm: 34.7421875
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.852582037448883
# Epoch 80 :
# Testing accuracy: 67.70429992675781 %; detection rate: 63.567970275878906; false alarm: 28.15937042236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 17.157250612974167
# Epoch 81 :
# Testing accuracy: 67.73125457763672 %; detection rate: 66.12344360351562; false alarm: 30.660934448242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 17.263051837682724
# Epoch 82 :
# Testing accuracy: 67.93828582763672 %; detection rate: 64.46406555175781; false alarm: 28.587493896484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 17.040106400847435
# Epoch 83 :
# Testing accuracy: 67.79296875 %; detection rate: 65.82421875; false alarm: 30.23828125
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.652985885739326
# Epoch 84 :
# Testing accuracy: 67.90274047851562 %; detection rate: 68.83281707763672; false alarm: 33.02734375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.915205895900726
# Epoch 85 :
# Testing accuracy: 67.8707046508789 %; detection rate: 66.49453735351562; false alarm: 30.75312042236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.796201646327972
# Epoch 86 :
# Testing accuracy: 67.4820327758789 %; detection rate: 64.86640930175781; false alarm: 29.90234375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.65025407075882
# Epoch 87 :
# Testing accuracy: 67.76679992675781 %; detection rate: 68.5679702758789; false alarm: 33.03437042236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 15.75648757815361
# Epoch 88 :
# Testing accuracy: 67.53125 %; detection rate: 73.1773452758789; false alarm: 38.11484146118164
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.861210733652115
# Epoch 89 :
# Testing accuracy: 67.5703125 %; detection rate: 67.09375; false alarm: 31.953125
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.59175707399845
# Epoch 90 :
# Testing accuracy: 67.83086395263672 %; detection rate: 66.2007827758789; false alarm: 30.5390625
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.4055734872818
# Epoch 91 :
# Testing accuracy: 67.75273895263672 %; detection rate: 66.1500015258789; false alarm: 30.64453125
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.359090074896812
# Epoch 92 :
# Testing accuracy: 67.85820770263672 %; detection rate: 63.86562728881836; false alarm: 28.149215698242188
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.117356836795807
# Epoch 93 :
# Testing accuracy: 67.50469207763672 %; detection rate: 62.837501525878906; false alarm: 27.828125
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 15.632400646805763
# Epoch 94 :
# Testing accuracy: 67.6792984008789 %; detection rate: 68.25703430175781; false alarm: 32.8984375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 15.905616104602814
# Epoch 95 :
# Testing accuracy: 67.70977020263672 %; detection rate: 68.38203430175781; false alarm: 32.962493896484375
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.13794769346714
# Epoch 96 :
# Testing accuracy: 67.72891235351562 %; detection rate: 67.40234375; false alarm: 31.94452667236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 15.845779463648796
# Epoch 97 :
# Testing accuracy: 67.7652359008789 %; detection rate: 69.703125; false alarm: 34.17265319824219
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 16.36292440444231
# Epoch 98 :
# Testing accuracy: 67.80195617675781 %; detection rate: 66.4703140258789; false alarm: 30.86640167236328
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 15.753596857190132
# Epoch 99 :
# Testing accuracy: 67.78515625 %; detection rate: 67.61016082763672; false alarm: 32.03984069824219
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 15.63924939930439
# Epoch 100 :
# Testing accuracy: 67.60000610351562 %; detection rate: 65.12422180175781; false alarm: 29.924217224121094
# Learning rate: 0.0005
# Max accuracy: 69.74648833274841 %; training loss: , 15.459555849432945
# statics saved to excel: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/DeepSenseHalf/VaryVolum/20_230117_22_11/convergSNR-6.xlsx
# Time spent for running100epochs 0:05:44.667735
# Testing accuracy: 56.302738189697266 %; detection rate: 99.88203430175781; false alarm: 87.27656555175781
# Testing accuracy: 56.525001525878906 %; detection rate: 99.87187957763672; false alarm: 86.8218765258789
# Testing accuracy: 56.79336166381836 %; detection rate: 99.8570327758789; false alarm: 86.27030944824219
# Testing accuracy: 56.96406555175781 %; detection rate: 99.83281707763672; false alarm: 85.9046859741211
# Testing accuracy: 57.192970275878906 %; detection rate: 99.8296890258789; false alarm: 85.4437484741211
# Testing accuracy: 57.48750305175781 %; detection rate: 99.8179702758789; false alarm: 84.84297180175781
# Testing accuracy: 57.67695617675781 %; detection rate: 99.79609680175781; false alarm: 84.44218444824219
# Testing accuracy: 57.92070770263672 %; detection rate: 99.76094055175781; false alarm: 83.9195327758789
# Testing accuracy: 58.181251525878906 %; detection rate: 99.75000762939453; false alarm: 83.38749694824219
# Testing accuracy: 58.405860900878906 %; detection rate: 99.7281265258789; false alarm: 82.9164047241211
# Testing accuracy: 58.667972564697266 %; detection rate: 99.68750762939453; false alarm: 82.3515625
# Testing accuracy: 58.90156555175781 %; detection rate: 99.66875457763672; false alarm: 81.8656234741211
# Testing accuracy: 59.109378814697266 %; detection rate: 99.6343765258789; false alarm: 81.4156265258789
# Testing accuracy: 59.328128814697266 %; detection rate: 99.5640640258789; false alarm: 80.9078140258789
# Testing accuracy: 59.710548400878906 %; detection rate: 99.54922485351562; false alarm: 80.12812805175781
# Testing accuracy: 59.909767150878906 %; detection rate: 99.49453735351562; false alarm: 79.67500305175781
# Testing accuracy: 60.11992645263672 %; detection rate: 99.3960952758789; false alarm: 79.15625
# Testing accuracy: 60.425785064697266 %; detection rate: 99.3765640258789; false alarm: 78.5250015258789
# Testing accuracy: 60.66484832763672 %; detection rate: 99.2867202758789; false alarm: 77.95703125
# Testing accuracy: 60.939456939697266 %; detection rate: 99.17422485351562; false alarm: 77.2953109741211
# Testing accuracy: 61.24336242675781 %; detection rate: 99.09375762939453; false alarm: 76.6070327758789
# Testing accuracy: 61.54766082763672 %; detection rate: 99.0093765258789; false alarm: 75.9140625
# Testing accuracy: 61.86367416381836 %; detection rate: 98.83672332763672; false alarm: 75.109375
# Testing accuracy: 62.103519439697266 %; detection rate: 98.70938110351562; false alarm: 74.5023422241211
# Testing accuracy: 62.43828582763672 %; detection rate: 98.5796890258789; false alarm: 73.703125
# Testing accuracy: 62.720314025878906 %; detection rate: 98.36172485351562; false alarm: 72.92109680175781
# Testing accuracy: 63.03008270263672 %; detection rate: 98.12578582763672; false alarm: 72.06562805175781
# Testing accuracy: 63.341800689697266 %; detection rate: 97.81953430175781; false alarm: 71.13594055175781
# Testing accuracy: 63.72500228881836 %; detection rate: 97.56875610351562; false alarm: 70.11874389648438
# Testing accuracy: 64.091796875 %; detection rate: 97.21953582763672; false alarm: 69.03593444824219
# Testing accuracy: 64.376953125 %; detection rate: 96.7320327758789; false alarm: 67.97811889648438
# Testing accuracy: 64.7203140258789 %; detection rate: 96.27656555175781; false alarm: 66.8359375
# Testing accuracy: 65.0660171508789 %; detection rate: 95.74610137939453; false alarm: 65.61405944824219
# Testing accuracy: 65.45703125 %; detection rate: 95.1851577758789; false alarm: 64.27108764648438
# Testing accuracy: 65.74336242675781 %; detection rate: 94.3375015258789; false alarm: 62.85078048706055
# Testing accuracy: 66.103515625 %; detection rate: 93.54531860351562; false alarm: 61.338279724121094
# Testing accuracy: 66.50430297851562 %; detection rate: 92.54922485351562; false alarm: 59.54062271118164
# Testing accuracy: 66.888671875 %; detection rate: 91.6382827758789; false alarm: 57.86093521118164
# Testing accuracy: 67.14961242675781 %; detection rate: 90.51406860351562; false alarm: 56.214839935302734
# Testing accuracy: 67.560546875 %; detection rate: 89.20313262939453; false alarm: 54.082027435302734
# Testing accuracy: 67.876953125 %; detection rate: 87.7750015258789; false alarm: 52.02109146118164
# Testing accuracy: 68.2164077758789 %; detection rate: 86.38125610351562; false alarm: 49.94843673706055
# Testing accuracy: 68.56562805175781 %; detection rate: 84.57500457763672; false alarm: 47.443748474121094
# Testing accuracy: 68.8921890258789 %; detection rate: 82.88282012939453; false alarm: 45.09843444824219
# Testing accuracy: 68.95039367675781 %; detection rate: 81.0015640258789; false alarm: 43.10077667236328
# Testing accuracy: 69.130859375 %; detection rate: 78.921875; false alarm: 40.660152435302734
# Testing accuracy: 69.4058609008789 %; detection rate: 76.86797332763672; false alarm: 38.05624771118164
# Testing accuracy: 69.5234375 %; detection rate: 74.6382827758789; false alarm: 35.591400146484375
# Testing accuracy: 69.57070922851562 %; detection rate: 72.32891082763672; false alarm: 33.1875
# Testing accuracy: 69.71797180175781 %; detection rate: 70.31875610351562; false alarm: 30.8828125
# Testing accuracy: 69.5914077758789 %; detection rate: 67.8570327758789; false alarm: 28.674217224121094
# Testing accuracy: 69.7496109008789 %; detection rate: 65.4625015258789; false alarm: 25.963279724121094
# Testing accuracy: 69.60625457763672 %; detection rate: 63.070316314697266; false alarm: 23.857810974121094
# Testing accuracy: 69.57070922851562 %; detection rate: 60.695316314697266; false alarm: 21.55390167236328
# Testing accuracy: 69.52265930175781 %; detection rate: 58.48750305175781; false alarm: 19.442184448242188
# Testing accuracy: 69.275390625 %; detection rate: 56.251564025878906; false alarm: 17.700775146484375
# Testing accuracy: 69.05313110351562 %; detection rate: 53.92422103881836; false alarm: 15.817962646484375
# Testing accuracy: 68.767578125 %; detection rate: 51.79609680175781; false alarm: 14.260932922363281
# Testing accuracy: 68.50508117675781 %; detection rate: 49.687503814697266; false alarm: 12.677337646484375
# Testing accuracy: 68.24649047851562 %; detection rate: 47.622657775878906; false alarm: 11.129684448242188
# Testing accuracy: 67.87890625 %; detection rate: 45.70234680175781; false alarm: 9.944526672363281
# Testing accuracy: 67.51016235351562 %; detection rate: 43.739845275878906; false alarm: 8.719528198242188
# Testing accuracy: 67.32929992675781 %; detection rate: 42.289066314697266; false alarm: 7.630462646484375
# Testing accuracy: 67.01171875 %; detection rate: 40.60390853881836; false alarm: 6.580467224121094
# Testing accuracy: 66.61211395263672 %; detection rate: 39.04296875; false alarm: 5.818748474121094
# Testing accuracy: 66.326171875 %; detection rate: 37.68984603881836; false alarm: 5.037498474121094
# Testing accuracy: 66.015625 %; detection rate: 36.368751525878906; false alarm: 4.337493896484375
# Testing accuracy: 65.67304992675781 %; detection rate: 35.12343978881836; false alarm: 3.7773361206054688
# Testing accuracy: 65.32421875 %; detection rate: 33.927345275878906; false alarm: 3.278900146484375
# Testing accuracy: 65.04336547851562 %; detection rate: 32.88671875; false alarm: 2.7999954223632812
# Testing accuracy: 64.68594360351562 %; detection rate: 31.78359603881836; false alarm: 2.411712646484375
# Testing accuracy: 64.35625457763672 %; detection rate: 30.805469512939453; false alarm: 2.0929641723632812
# Testing accuracy: 64.01289367675781 %; detection rate: 29.84609603881836; false alarm: 1.8203048706054688
# Testing accuracy: 63.76094055175781 %; detection rate: 29.106250762939453; false alarm: 1.5843734741210938
# Testing accuracy: 63.466407775878906 %; detection rate: 28.31953239440918; false alarm: 1.3867111206054688
# Testing accuracy: 63.199222564697266 %; detection rate: 27.602344512939453; false alarm: 1.2039031982421875
# Testing accuracy: 62.95234680175781 %; detection rate: 26.965625762939453; false alarm: 1.0609359741210938
# Testing accuracy: 62.72578430175781 %; detection rate: 26.314064025878906; false alarm: 0.8624954223632812
# Testing accuracy: 62.369144439697266 %; detection rate: 25.54609489440918; false alarm: 0.8078079223632812
# Testing accuracy: 62.125003814697266 %; detection rate: 24.950782775878906; false alarm: 0.700775146484375
# Testing accuracy: 61.87812805175781 %; detection rate: 24.392189025878906; false alarm: 0.6359329223632812
# Testing accuracy: 61.733985900878906 %; detection rate: 23.97578239440918; false alarm: 0.5078048706054688
# Testing accuracy: 61.49726867675781 %; detection rate: 23.480470657348633; false alarm: 0.485931396484375
# Testing accuracy: 61.275001525878906 %; detection rate: 22.94453239440918; false alarm: 0.39452362060546875
# Testing accuracy: 61.09414291381836 %; detection rate: 22.557031631469727; false alarm: 0.368743896484375
# Testing accuracy: 60.83242416381836 %; detection rate: 21.98750114440918; false alarm: 0.32265472412109375
# Testing accuracy: 60.607425689697266 %; detection rate: 21.507814407348633; false alarm: 0.29296112060546875
# Testing accuracy: 60.42422103881836 %; detection rate: 21.107812881469727; false alarm: 0.259368896484375
# Testing accuracy: 60.189064025878906 %; detection rate: 20.59687614440918; false alarm: 0.21874237060546875
# Testing accuracy: 60.07148742675781 %; detection rate: 20.351564407348633; false alarm: 0.208587646484375
# Testing accuracy: 59.845706939697266 %; detection rate: 19.89453125; false alarm: 0.20311737060546875
# Testing accuracy: 59.64922332763672 %; detection rate: 19.49140739440918; false alarm: 0.192962646484375
# Testing accuracy: 59.488285064697266 %; detection rate: 19.13984489440918; false alarm: 0.16327667236328125
# Testing accuracy: 59.28398895263672 %; detection rate: 18.704689025878906; false alarm: 0.13671112060546875
# Testing accuracy: 59.05390930175781 %; detection rate: 18.232032775878906; false alarm: 0.12421417236328125
# Testing accuracy: 58.96133041381836 %; detection rate: 18.04218864440918; false alarm: 0.11952972412109375
# Testing accuracy: 58.76211166381836 %; detection rate: 17.64453125; false alarm: 0.12030792236328125
# Testing accuracy: 58.622657775878906 %; detection rate: 17.3359375; false alarm: 0.0906219482421875
# Testing accuracy: 58.42266082763672 %; detection rate: 16.939064025878906; false alarm: 0.09374237060546875
# Testing accuracy: 58.32461166381836 %; detection rate: 16.725000381469727; false alarm: 0.075775146484375
# ROC in Excel saved to: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/DeepSenseHalf/VaryVolum/20_230117_22_11/ROC_SNR-6.xlsx
# ROC in Lists saved to: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/DeepSenseHalf/VaryVolum/20_230117_22_11/DeepSenseHalfROC.pth
# Dataset description: cleanPSD64.pth, SNR-6dB, 10bands, 6PUs, 64pts/band.
# 3.2791123390197754 2.5341572761535645
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1               [-1, 8, 640]              48
#             Conv1d-2               [-1, 8, 640]             328
#             Conv1d-3              [-1, 16, 320]             656
#             Conv1d-4              [-1, 16, 320]           1,296
#             Linear-5                   [-1, 10]          25,610
# ================================================================
# Total params: 27,938
# Trainable params: 27,938
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.16
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.27
# ----------------------------------------------------------------
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv1d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# macs are :
#  870400.0
# params are :
#  27938.0
# model watermark 230117_22_20
# Model saved to dir:
#  /content/drive/MyDrive/Wireless_Transformer/Saved_Models/DeepSenseHalf/VaryVolum/50_230117_22_20/DeepSenseHalf_SNR-6vol50.pth
# Epoch 1 :
# Testing accuracy: 49.845706939697266 %; detection rate: 43.85000228881836; false alarm: 44.158592224121094
# Learning rate: 0.0005
# Max accuracy: 49.845704436302185 %; training loss: , 44.122472167015076
# Epoch 2 :
# Testing accuracy: 63.48672103881836 %; detection rate: 76.64922332763672; false alarm: 49.675777435302734
# Learning rate: 0.0005
# Max accuracy: 63.48671913146973 %; training loss: , 38.222706854343414
# Epoch 3 :
# Testing accuracy: 68.56172180175781 %; detection rate: 63.453128814697266; false alarm: 26.329681396484375
# Learning rate: 0.0005
# Max accuracy: 68.5617208480835 %; training loss: , 34.15935888886452
# Epoch 4 :
# Testing accuracy: 69.54609680175781 %; detection rate: 67.58984375; false alarm: 28.497650146484375
# Learning rate: 0.0005
# Max accuracy: 69.54609751701355 %; training loss: , 33.169866889715195
# Epoch 5 :
# Testing accuracy: 69.38671875 %; detection rate: 64.48281860351562; false alarm: 25.709373474121094
# Learning rate: 0.0005
# Max accuracy: 69.54609751701355 %; training loss: , 32.55559614300728
# Epoch 6 :
# Testing accuracy: 69.92852020263672 %; detection rate: 63.101566314697266; false alarm: 23.244529724121094
# Learning rate: 0.0005
# Max accuracy: 69.92852091789246 %; training loss: , 32.27556648850441
# Epoch 7 :
# Testing accuracy: 69.9839859008789 %; detection rate: 58.759376525878906; false alarm: 18.791404724121094
# Learning rate: 0.0005
# Max accuracy: 69.98398900032043 %; training loss: , 31.863660395145416
# Epoch 8 :
# Testing accuracy: 70.10039520263672 %; detection rate: 78.17266082763672; false alarm: 37.97187042236328
# Learning rate: 0.0005
# Max accuracy: 70.10039687156677 %; training loss: , 31.53206515312195
# Epoch 9 :
# Testing accuracy: 70.69258117675781 %; detection rate: 71.70625305175781; false alarm: 30.321090698242188
# Learning rate: 0.0005
# Max accuracy: 70.69258093833923 %; training loss: , 31.23854821920395
# Epoch 10 :
# Testing accuracy: 70.9488296508789 %; detection rate: 72.52734375; false alarm: 30.629684448242188
# Learning rate: 0.0005
# Max accuracy: 70.94883322715759 %; training loss: , 30.94395723938942
# Epoch 11 :
# Testing accuracy: 70.92578125 %; detection rate: 72.4921875; false alarm: 30.640625
# Learning rate: 0.0005
# Max accuracy: 70.94883322715759 %; training loss: , 30.741916984319687
# Epoch 12 :
# Testing accuracy: 70.88906860351562 %; detection rate: 74.83203125; false alarm: 33.05390167236328
# Learning rate: 0.0005
# Max accuracy: 70.94883322715759 %; training loss: , 30.417546898126602
# Epoch 13 :
# Testing accuracy: 70.73906707763672 %; detection rate: 60.14375305175781; false alarm: 18.665618896484375
# Learning rate: 0.0005
# Max accuracy: 70.94883322715759 %; training loss: , 30.476073533296585
# Epoch 14 :
# Testing accuracy: 71.12812805175781 %; detection rate: 64.5210952758789; false alarm: 22.26483917236328
# Learning rate: 0.0005
# Max accuracy: 71.12812995910645 %; training loss: , 30.274490654468536
# Epoch 15 :
# Testing accuracy: 70.83711242675781 %; detection rate: 76.3843765258789; false alarm: 34.71015167236328
# Learning rate: 0.0005
# Max accuracy: 71.12812995910645 %; training loss: , 29.884751111268997
# Epoch 16 :
# Testing accuracy: 71.13359832763672 %; detection rate: 70.42656707763672; false alarm: 28.15937042236328
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 29.702413111925125
# Epoch 17 :
# Testing accuracy: 70.83477020263672 %; detection rate: 76.8179702758789; false alarm: 35.1484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 29.477324336767197
# Epoch 18 :
# Testing accuracy: 71.05390930175781 %; detection rate: 73.7359390258789; false alarm: 31.62812042236328
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 29.35359415411949
# Epoch 19 :
# Testing accuracy: 71.12773895263672 %; detection rate: 66.96484375; false alarm: 24.709373474121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 29.10164725780487
# Epoch 20 :
# Testing accuracy: 70.8082046508789 %; detection rate: 68.14531707763672; false alarm: 26.528900146484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 28.837405294179916
# Epoch 21 :
# Testing accuracy: 70.78047180175781 %; detection rate: 75.44921875; false alarm: 33.888275146484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 28.880976736545563
# Epoch 22 :
# Testing accuracy: 71.0859375 %; detection rate: 69.39765930175781; false alarm: 27.22577667236328
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 28.562537252902985
# Epoch 23 :
# Testing accuracy: 71.0562515258789 %; detection rate: 71.2281265258789; false alarm: 29.115623474121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 28.46350309252739
# Epoch 24 :
# Testing accuracy: 70.96719360351562 %; detection rate: 68.91875457763672; false alarm: 26.984375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 28.474781066179276
# Epoch 25 :
# Testing accuracy: 70.97930145263672 %; detection rate: 70.15859985351562; false alarm: 28.199996948242188
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 28.047315001487732
# Epoch 26 :
# Testing accuracy: 70.79531860351562 %; detection rate: 67.73125457763672; false alarm: 26.140625
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 28.11386528611183
# Epoch 27 :
# Testing accuracy: 70.998046875 %; detection rate: 67.66875457763672; false alarm: 25.672653198242188
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 28.008440554142
# Epoch 28 :
# Testing accuracy: 70.81758117675781 %; detection rate: 64.8609390258789; false alarm: 23.22577667236328
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 27.934059023857117
# Epoch 29 :
# Testing accuracy: 70.9644546508789 %; detection rate: 70.61640930175781; false alarm: 28.6875
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 27.55804181098938
# Epoch 30 :
# Testing accuracy: 70.73945617675781 %; detection rate: 70.9296875; false alarm: 29.450775146484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 27.417487651109695
# Epoch 31 :
# Testing accuracy: 70.5757827758789 %; detection rate: 71.98516082763672; false alarm: 30.833587646484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 27.423363119363785
# Epoch 32 :
# Testing accuracy: 70.6953125 %; detection rate: 68.37890625; false alarm: 26.98828125
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 27.423130959272385
# Epoch 33 :
# Testing accuracy: 70.56094360351562 %; detection rate: 72.27812957763672; false alarm: 31.15625
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 27.238268226385117
# Epoch 34 :
# Testing accuracy: 70.5425796508789 %; detection rate: 68.4859390258789; false alarm: 27.400779724121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 27.118205219507217
# Epoch 35 :
# Testing accuracy: 70.458984375 %; detection rate: 68.5546875; false alarm: 27.63671875
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 26.84689861536026
# Epoch 36 :
# Testing accuracy: 70.30899047851562 %; detection rate: 73.40859985351562; false alarm: 32.790618896484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 26.766239315271378
# Epoch 37 :
# Testing accuracy: 70.451171875 %; detection rate: 68.55156707763672; false alarm: 27.649215698242188
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 26.704195141792297
# Epoch 38 :
# Testing accuracy: 70.39336395263672 %; detection rate: 73.21875; false alarm: 32.432029724121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 26.877408146858215
# Epoch 39 :
# Testing accuracy: 70.28633117675781 %; detection rate: 73.07891082763672; false alarm: 32.506248474121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 26.44123864173889
# Epoch 40 :
# Testing accuracy: 70.41680145263672 %; detection rate: 65.94453430175781; false alarm: 25.110931396484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 26.399284034967422
# Epoch 41 :
# Testing accuracy: 70.26171875 %; detection rate: 67.7906265258789; false alarm: 27.267181396484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 26.451849192380905
# Epoch 42 :
# Testing accuracy: 69.98867797851562 %; detection rate: 71.42266082763672; false alarm: 31.4453125
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 26.09326097369194
# Epoch 43 :
# Testing accuracy: 70.2710952758789 %; detection rate: 67.50703430175781; false alarm: 26.96484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 26.206675350666046
# Epoch 44 :
# Testing accuracy: 70.33203125 %; detection rate: 68.85781860351562; false alarm: 28.193748474121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.847827196121216
# Epoch 45 :
# Testing accuracy: 70.26445770263672 %; detection rate: 69.21406555175781; false alarm: 28.685150146484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.728830069303513
# Epoch 46 :
# Testing accuracy: 70.1128921508789 %; detection rate: 68.36563110351562; false alarm: 28.13983917236328
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.90775951743126
# Epoch 47 :
# Testing accuracy: 70.1640625 %; detection rate: 68.4703140258789; false alarm: 28.142181396484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.529274702072144
# Epoch 48 :
# Testing accuracy: 69.84609985351562 %; detection rate: 69.47344207763672; false alarm: 29.78125
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.678254276514053
# Epoch 49 :
# Testing accuracy: 69.93437957763672 %; detection rate: 68.0132827758789; false alarm: 28.14453125
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.45587620139122
# Epoch 50 :
# Testing accuracy: 70.10195922851562 %; detection rate: 67.98046875; false alarm: 27.77655792236328
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.77717614173889
# Epoch 51 :
# Testing accuracy: 69.998046875 %; detection rate: 70.02812957763672; false alarm: 30.032028198242188
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.387579411268234
# Epoch 52 :
# Testing accuracy: 69.73320770263672 %; detection rate: 74.01953125; false alarm: 34.553123474121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.41660326719284
# Epoch 53 :
# Testing accuracy: 69.97539520263672 %; detection rate: 71.33203125; false alarm: 31.381248474121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.165812224149704
# Epoch 54 :
# Testing accuracy: 69.8824234008789 %; detection rate: 68.11016082763672; false alarm: 28.345306396484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.1325241625309
# Epoch 55 :
# Testing accuracy: 69.76250457763672 %; detection rate: 72.66796875; false alarm: 33.142967224121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.878494828939438
# Epoch 56 :
# Testing accuracy: 69.8199234008789 %; detection rate: 68.046875; false alarm: 28.407028198242188
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 25.11333540081978
# Epoch 57 :
# Testing accuracy: 70.0625 %; detection rate: 69.51875305175781; false alarm: 29.39374542236328
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.77399843931198
# Epoch 58 :
# Testing accuracy: 70.11758422851562 %; detection rate: 69.65937805175781; false alarm: 29.424217224121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.87265369296074
# Epoch 59 :
# Testing accuracy: 69.69453430175781 %; detection rate: 69.94844055175781; false alarm: 30.559371948242188
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.833219975233078
# Epoch 60 :
# Testing accuracy: 69.54336547851562 %; detection rate: 69.06484985351562; false alarm: 29.978118896484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.796956658363342
# Epoch 61 :
# Testing accuracy: 69.62890625 %; detection rate: 68.8257827758789; false alarm: 29.567962646484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.308682650327682
# Epoch 62 :
# Testing accuracy: 69.7007827758789 %; detection rate: 69.11797332763672; false alarm: 29.716400146484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.441934019327164
# Epoch 63 :
# Testing accuracy: 69.76016235351562 %; detection rate: 68.93281555175781; false alarm: 29.412498474121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.42072907090187
# Epoch 64 :
# Testing accuracy: 69.37422180175781 %; detection rate: 71.58984375; false alarm: 32.841400146484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.523474663496017
# Epoch 65 :
# Testing accuracy: 69.61250305175781 %; detection rate: 67.26171875; false alarm: 28.036712646484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.155945271253586
# Epoch 66 :
# Testing accuracy: 69.47930145263672 %; detection rate: 67.33984375; false alarm: 28.381248474121094
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.147483110427856
# Epoch 67 :
# Testing accuracy: 69.65117645263672 %; detection rate: 68.6812515258789; false alarm: 29.37890625
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.219491451978683
# Epoch 68 :
# Testing accuracy: 69.29609680175781 %; detection rate: 68.984375; false alarm: 30.392181396484375
# Learning rate: 0.0005
# Max accuracy: 71.13359570503235 %; training loss: , 24.298162013292313
# Epoch 69 :
# ...
# Max accuracy: 74.12148714065552 %; training loss: , 93.03585469722748
# Epoch 87 :
# Testing accuracy: 74.0777359008789 %; detection rate: 73.72265625; false alarm: 25.567184448242188
# Learning rate: 0.0005
# Max accuracy: 74.12148714065552 %; training loss: , 93.06969174742699
# Epoch 88 :
# Testing accuracy: 73.9566421508789 %; detection rate: 73.56484985351562; false alarm: 25.65155792236328
# Learning rate: 0.0005
# Max accuracy: 74.12148714065552 %; training loss: , 93.0304445028305
# Epoch 89 :
# Testing accuracy: 73.95352172851562 %; detection rate: 68.80313110351562; false alarm: 20.896087646484375
# Learning rate: 0.0005
# Max accuracy: 74.12148714065552 %; training loss: , 93.07231158018112
# Epoch 90 :
# Testing accuracy: 74.04727172851562 %; detection rate: 72.25625610351562; false alarm: 24.161712646484375
# Learning rate: 0.0005
# Max accuracy: 74.12148714065552 %; training loss: , 93.11775895953178
# Epoch 91 :
# Testing accuracy: 74.03828430175781 %; detection rate: 74.16719055175781; false alarm: 26.090621948242188
# Learning rate: 0.0005
# Max accuracy: 74.12148714065552 %; training loss: , 93.17089033126831
# Epoch 92 :
# Testing accuracy: 74.16836547851562 %; detection rate: 72.00625610351562; false alarm: 23.669525146484375
# Learning rate: 0.0005
# Max accuracy: 74.16836023330688 %; training loss: , 92.96770212054253
# Epoch 93 :
# Testing accuracy: 74.111328125 %; detection rate: 71.92031860351562; false alarm: 23.697654724121094
# Learning rate: 0.0005
# Max accuracy: 74.16836023330688 %; training loss: , 93.0854209959507
# Epoch 94 :
# Testing accuracy: 74.03515625 %; detection rate: 72.28047180175781; false alarm: 24.21015167236328
# Learning rate: 0.0005
# Max accuracy: 74.16836023330688 %; training loss: , 93.10157680511475
# Epoch 95 :
# Testing accuracy: 74.08477020263672 %; detection rate: 71.01484680175781; false alarm: 22.845306396484375
# Learning rate: 0.0005
# Max accuracy: 74.16836023330688 %; training loss: , 93.0811054110527
# Epoch 96 :
# Testing accuracy: 74.05703735351562 %; detection rate: 73.17109680175781; false alarm: 25.057029724121094
# Learning rate: 0.0005
# Max accuracy: 74.16836023330688 %; training loss: , 93.05866572260857
# Epoch 97 :
# Testing accuracy: 74.07891082763672 %; detection rate: 70.20625305175781; false alarm: 22.048431396484375
# Learning rate: 0.0005
# Max accuracy: 74.16836023330688 %; training loss: , 93.13000893592834
# Epoch 98 :
# Testing accuracy: 74.0308609008789 %; detection rate: 73.16015625; false alarm: 25.098434448242188
# Learning rate: 0.0005
# Max accuracy: 74.16836023330688 %; training loss: , 93.15550741553307
# Epoch 99 :
# Testing accuracy: 73.9703140258789 %; detection rate: 72.5367202758789; false alarm: 24.596092224121094
# Learning rate: 0.0005
# Max accuracy: 74.16836023330688 %; training loss: , 93.00508213043213
# Epoch 100 :
# Testing accuracy: 74.12617492675781 %; detection rate: 71.67266082763672; false alarm: 23.420310974121094
# Learning rate: 0.0005
# Max accuracy: 74.16836023330688 %; training loss: , 92.98170733451843
# statics saved to excel: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/DeepSenseHalf/VaryVolum/1600_230117_23_25/convergSNR-6.xlsx
# Time spent for running100epochs 0:13:06.687536
# Testing accuracy: 58.40273666381836 %; detection rate: 99.86563110351562; false alarm: 83.0601577758789
# Testing accuracy: 58.595706939697266 %; detection rate: 99.88906860351562; false alarm: 82.6976547241211
# Testing accuracy: 58.86054992675781 %; detection rate: 99.87110137939453; false alarm: 82.1500015258789
# Testing accuracy: 59.060550689697266 %; detection rate: 99.85078430175781; false alarm: 81.72969055175781
# Testing accuracy: 59.319923400878906 %; detection rate: 99.83203887939453; false alarm: 81.19218444824219
# Testing accuracy: 59.51055145263672 %; detection rate: 99.81484985351562; false alarm: 80.79374694824219
# Testing accuracy: 59.73086166381836 %; detection rate: 99.78359985351562; false alarm: 80.3218765258789
# Testing accuracy: 60.025394439697266 %; detection rate: 99.76563262939453; false alarm: 79.71484375
# Testing accuracy: 60.339454650878906 %; detection rate: 99.72578430175781; false alarm: 79.046875
# Testing accuracy: 60.59453582763672 %; detection rate: 99.71015930175781; false alarm: 78.5210952758789
# Testing accuracy: 60.84804916381836 %; detection rate: 99.67500305175781; false alarm: 77.9789047241211
# Testing accuracy: 61.15117645263672 %; detection rate: 99.65156555175781; false alarm: 77.3492202758789
# Testing accuracy: 61.46367645263672 %; detection rate: 99.61328887939453; false alarm: 76.6859359741211
# Testing accuracy: 61.76406478881836 %; detection rate: 99.60625457763672; false alarm: 76.078125
# Testing accuracy: 62.04609680175781 %; detection rate: 99.54297637939453; false alarm: 75.4507827758789
# Testing accuracy: 62.40351867675781 %; detection rate: 99.50782012939453; false alarm: 74.7007827758789
# Testing accuracy: 62.67890930175781 %; detection rate: 99.45156860351562; false alarm: 74.09375
# Testing accuracy: 62.99453353881836 %; detection rate: 99.37969207763672; false alarm: 73.390625
# Testing accuracy: 63.263675689697266 %; detection rate: 99.3531265258789; false alarm: 72.8257827758789
# Testing accuracy: 63.59492492675781 %; detection rate: 99.2906265258789; false alarm: 72.10078430175781
# Testing accuracy: 63.81875228881836 %; detection rate: 99.16875457763672; false alarm: 71.53125
# Testing accuracy: 64.19453430175781 %; detection rate: 99.17813110351562; false alarm: 70.7890625
# Testing accuracy: 64.52734375 %; detection rate: 99.07500457763672; false alarm: 70.02030944824219
# Testing accuracy: 64.82148742675781 %; detection rate: 98.98750305175781; false alarm: 69.34452819824219
# Testing accuracy: 65.10859680175781 %; detection rate: 98.89063262939453; false alarm: 68.67343139648438
# Testing accuracy: 65.42813110351562 %; detection rate: 98.7867202758789; false alarm: 67.93046569824219
# Testing accuracy: 65.62969207763672 %; detection rate: 98.69844055175781; false alarm: 67.43905639648438
# Testing accuracy: 65.9937515258789 %; detection rate: 98.57734680175781; false alarm: 66.58984375
# Testing accuracy: 66.314453125 %; detection rate: 98.52344512939453; false alarm: 65.89453125
# Testing accuracy: 66.51055145263672 %; detection rate: 98.3882827758789; false alarm: 65.3671875
# Testing accuracy: 66.83438110351562 %; detection rate: 98.2710952758789; false alarm: 64.60234069824219
# Testing accuracy: 67.07148742675781 %; detection rate: 98.09453582763672; false alarm: 63.951560974121094
# Testing accuracy: 67.3570327758789 %; detection rate: 97.9585952758789; false alarm: 63.244529724121094
# Testing accuracy: 67.693359375 %; detection rate: 97.77031707763672; false alarm: 62.38359069824219
# Testing accuracy: 67.9117202758789 %; detection rate: 97.50234985351562; false alarm: 61.67890548706055
# Testing accuracy: 68.2421875 %; detection rate: 97.26406860351562; false alarm: 60.779685974121094
# Testing accuracy: 68.54531860351562 %; detection rate: 96.92578887939453; false alarm: 59.83515548706055
# Testing accuracy: 68.89297485351562 %; detection rate: 96.49219512939453; false alarm: 58.70624923706055
# Testing accuracy: 69.42656707763672 %; detection rate: 96.0367202758789; false alarm: 57.183589935302734
# Testing accuracy: 69.76289367675781 %; detection rate: 95.4156265258789; false alarm: 55.88984298706055
# Testing accuracy: 70.07656860351562 %; detection rate: 94.48438262939453; false alarm: 54.33124923706055
# Testing accuracy: 70.55313110351562 %; detection rate: 93.44922637939453; false alarm: 52.34296798706055
# Testing accuracy: 71.0738296508789 %; detection rate: 92.2046890258789; false alarm: 50.057029724121094
# Testing accuracy: 71.68399047851562 %; detection rate: 90.73516082763672; false alarm: 47.367183685302734
# Testing accuracy: 72.3492202758789 %; detection rate: 88.96094512939453; false alarm: 44.26249694824219
# Testing accuracy: 72.6695327758789 %; detection rate: 86.69219207763672; false alarm: 41.35312271118164
# Testing accuracy: 73.20195770263672 %; detection rate: 84.18750762939453; false alarm: 37.783592224121094
# Testing accuracy: 73.5078125 %; detection rate: 81.39297485351562; false alarm: 34.377342224121094
# Testing accuracy: 73.8140640258789 %; detection rate: 78.30703735351562; false alarm: 30.67890167236328
# Testing accuracy: 74.0425796508789 %; detection rate: 75.34375; false alarm: 27.258590698242188
# Testing accuracy: 74.08828735351562 %; detection rate: 72.00234985351562; false alarm: 23.825775146484375
# Testing accuracy: 74.04023742675781 %; detection rate: 68.5835952758789; false alarm: 20.50312042236328
# Testing accuracy: 73.76250457763672 %; detection rate: 65.33515930175781; false alarm: 17.810150146484375
# Testing accuracy: 73.5445327758789 %; detection rate: 62.26641082763672; false alarm: 15.177337646484375
# Testing accuracy: 73.244140625 %; detection rate: 59.232032775878906; false alarm: 12.743743896484375
# Testing accuracy: 72.78164672851562 %; detection rate: 56.38984680175781; false alarm: 10.826560974121094
# Testing accuracy: 72.4332046508789 %; detection rate: 53.87812805175781; false alarm: 9.011711120605469
# Testing accuracy: 71.82109832763672 %; detection rate: 51.29140853881836; false alarm: 7.6492156982421875
# Testing accuracy: 71.46328735351562 %; detection rate: 49.325782775878906; false alarm: 6.3992156982421875
# Testing accuracy: 71.04922485351562 %; detection rate: 47.470314025878906; false alarm: 5.3718719482421875
# Testing accuracy: 70.60469055175781 %; detection rate: 45.81718826293945; false alarm: 4.607810974121094
# Testing accuracy: 70.25312805175781 %; detection rate: 44.29609680175781; false alarm: 3.7898406982421875
# Testing accuracy: 69.86953735351562 %; detection rate: 42.968753814697266; false alarm: 3.2296829223632812
# Testing accuracy: 69.6328125 %; detection rate: 42.08671951293945; false alarm: 2.8210906982421875
# Testing accuracy: 69.267578125 %; detection rate: 40.945316314697266; false alarm: 2.4101486206054688
# Testing accuracy: 68.9761734008789 %; detection rate: 40.09453201293945; false alarm: 2.142181396484375
# Testing accuracy: 68.6363296508789 %; detection rate: 39.15547180175781; false alarm: 1.8828048706054688
# Testing accuracy: 68.34375 %; detection rate: 38.35469055175781; false alarm: 1.6671829223632812
# Testing accuracy: 68.0953140258789 %; detection rate: 37.72265625; false alarm: 1.5320281982421875
# Testing accuracy: 67.88008117675781 %; detection rate: 37.09375; false alarm: 1.333587646484375
# Testing accuracy: 67.72930145263672 %; detection rate: 36.657814025878906; false alarm: 1.1992111206054688
# Testing accuracy: 67.4546890258789 %; detection rate: 36.017189025878906; false alarm: 1.1078109741210938
# Testing accuracy: 67.16836547851562 %; detection rate: 35.30156326293945; false alarm: 0.9648361206054688
# Testing accuracy: 66.98554992675781 %; detection rate: 34.91875076293945; false alarm: 0.9476547241210938
# Testing accuracy: 66.75 %; detection rate: 34.3828125; false alarm: 0.8828048706054688
# Testing accuracy: 66.54375457763672 %; detection rate: 33.85625076293945; false alarm: 0.7687454223632812
# Testing accuracy: 66.34883117675781 %; detection rate: 33.411720275878906; false alarm: 0.7140579223632812
# Testing accuracy: 66.1187515258789 %; detection rate: 32.896095275878906; false alarm: 0.6585922241210938
# Testing accuracy: 65.91289520263672 %; detection rate: 32.40468978881836; false alarm: 0.5789031982421875
# Testing accuracy: 65.662109375 %; detection rate: 31.88203239440918; false alarm: 0.5578079223632812
# Testing accuracy: 65.45352172851562 %; detection rate: 31.421876907348633; false alarm: 0.5148391723632812
# Testing accuracy: 65.234375 %; detection rate: 30.957033157348633; false alarm: 0.48827362060546875
# Testing accuracy: 65.0269546508789 %; detection rate: 30.504688262939453; false alarm: 0.450775146484375
# Testing accuracy: 64.85430145263672 %; detection rate: 30.128908157348633; false alarm: 0.42031097412109375
# Testing accuracy: 64.6015625 %; detection rate: 29.571876525878906; false alarm: 0.368743896484375
# Testing accuracy: 64.44570922851562 %; detection rate: 29.23359489440918; false alarm: 0.34218597412109375
# Testing accuracy: 64.20156860351562 %; detection rate: 28.72109603881836; false alarm: 0.317962646484375
# Testing accuracy: 63.950782775878906 %; detection rate: 28.200000762939453; false alarm: 0.298431396484375
# Testing accuracy: 63.71758270263672 %; detection rate: 27.693750381469727; false alarm: 0.2585906982421875
# Testing accuracy: 63.589454650878906 %; detection rate: 27.42109489440918; false alarm: 0.24217987060546875
# Testing accuracy: 63.31289291381836 %; detection rate: 26.86250114440918; false alarm: 0.23671722412109375
# Testing accuracy: 63.167579650878906 %; detection rate: 26.543750762939453; false alarm: 0.208587646484375
# Testing accuracy: 62.95234680175781 %; detection rate: 26.10859489440918; false alarm: 0.2039031982421875
# Testing accuracy: 62.70156478881836 %; detection rate: 25.582033157348633; false alarm: 0.17890167236328125
# Testing accuracy: 62.52617645263672 %; detection rate: 25.213281631469727; false alarm: 0.1609344482421875
# Testing accuracy: 62.328128814697266 %; detection rate: 24.824220657348633; false alarm: 0.16796112060546875
# Testing accuracy: 62.087501525878906 %; detection rate: 24.302345275878906; false alarm: 0.12734222412109375
# Testing accuracy: 61.98672103881836 %; detection rate: 24.102344512939453; false alarm: 0.12889862060546875
# Testing accuracy: 61.75820541381836 %; detection rate: 23.626564025878906; false alarm: 0.1101531982421875
# Testing accuracy: 61.56289291381836 %; detection rate: 23.213281631469727; false alarm: 0.087493896484375
# ROC in Excel saved to: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/DeepSenseHalf/VaryVolum/1600_230117_23_25/ROC_SNR-6.xlsx
# ROC in Lists saved to: /content/drive/MyDrive/Wireless_Transformer/Saved_Models/DeepSenseHalf/VaryVolum/1600_230117_23_25/DeepSenseHalfROC.pth
# Dataset description: cleanPSD64.pth, SNR-6dB, 10bands, 6PUs, 64pts/band.
# 3.279839038848877 2.5345261096954346
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1               [-1, 8, 640]              48
#             Conv1d-2               [-1, 8, 640]             328
#             Conv1d-3              [-1, 16, 320]             656
#             Conv1d-4              [-1, 16, 320]           1,296
#             Linear-5                   [-1, 10]          25,610
# ================================================================
# Total params: 27,938
# Trainable params: 27,938
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.16
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.27
# ----------------------------------------------------------------
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv1d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# macs are :
#  870400.0
# params are :
#  27938.0
# model watermark 230117_23_44
# Model saved to dir:
#  /content/drive/MyDrive/Wireless_Transformer/Saved_Models/DeepSenseHalf/VaryVolum/2400_230117_23_44/DeepSenseHalf_SNR-6vol2400.pth
# Epoch 1 :
# Testing accuracy: 49.870704650878906 %; detection rate: 38.20937728881836; false alarm: 38.46796417236328
# Learning rate: 0.0005
# Max accuracy: 49.87070560455322 %; training loss: , 166.08079105615616
# Epoch 2 :
# Testing accuracy: 71.67266082763672 %; detection rate: 74.88359832763672; false alarm: 31.53827667236328
# Learning rate: 0.0005
# Max accuracy: 71.67266011238098 %; training loss: , 149.57601621747017
# Epoch 3 :
# Testing accuracy: 72.6421890258789 %; detection rate: 73.99140930175781; false alarm: 28.70703125
# Learning rate: 0.0005
# Max accuracy: 72.64218926429749 %; training loss: , 147.21439808607101
# Epoch 4 :
# Testing accuracy: 73.1148452758789 %; detection rate: 70.34375; false alarm: 24.114059448242188
# Learning rate: 0.0005
# Max accuracy: 73.11484813690186 %; training loss: , 145.81015986204147
# Epoch 5 :

# %%
# v = DeepSense(num_classes = labels_te[0].size(0)).to(device) 
# summary(v, (1,640)) #show model details
# macs, params = profile(v.to('cpu'), inputs =(torch.randn(1, 640), )) #model on CPU
# print('macs are :\n',macs)
# print('params are :\n',params)

# %%
# plt.title("ROC of " +type(v).__name__+ " method in SNR="+str(SNR)+"dB")
# l2, = plt.plot(pfa2, pd2, color='green', label='Transformer')
# plt.legend(loc='lower right')
# plt.show()

# %%
from google.colab import runtime
runtime.unassign()

# %%
# # same as last cell
# dfroc = pd.DataFrame() # save statics to excel
# # df1['acc_old'] = xx
# dfroc['PD'] = pd2
# dfroc['PFA'] = pfa2

# with pd.ExcelWriter(address_model + "ROC_SNR"+str(SNR)+".xlsx", mode='w') as writer:  #mode was 'a'
#   dfroc.to_excel(writer, sheet_name=type(v).__name__)
# print('Statics saved to excel:', address_model + "ROC_SNR"+str(SNR)+".xlsx")

# %%
# load results from other tests, e.g. WrTROC.pth. 
# ROC_dict=torch.load('/content/drive/MyDrive/Wireless_Transformer/Saved_Models/WrTOct26/221027_23_41/WrTOct26ROC.pth')  #load another result for reference
# plt.title("ROC of several methods at SNR="+str(SNR)+'dB')
# # l1, = plt.plot(pfa, pd, color='blue',label='EnergyDetection1')
# l2, = plt.plot(ROC_dict['pfa'], ROC_dict['pd'], color='red', label='Transformer')
# l3, = plt.plot(pfa2, pd2, color='green', label='DNN')
# plt.legend(loc='lower right')
# plt.show()
